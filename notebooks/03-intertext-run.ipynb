# %%
import glob
import os
from collections import Counter
from itertools import combinations

import numpy as np
np.random.seed(18012023)

import pandas as pd
pd.set_option('display.max_colwidth', 0)

import seaborn as sb

from sklearn.metrics import pairwise_distances
import lxml.etree
from scipy.spatial.distance import pdist, squareform
from tqdm import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer

import matplotlib.pyplot as plt
import matplotlib
plt.rcParams['figure.dpi'] = 300
plt.rcParams['font.family'] = 'Arial'

# %% [markdown]
# In this notebook, we run the intertext retrieval (with the calibrated parameters) on all of the narrative (epic) texts available on the *Cd-rom Middelnederlands*. We dump the results to a spreadsheet that we will statistically analyze in the next notebook.
#
# First we make sure that the output direcotry exists:

# %%
fig_dir = '../figures'
if not os.path.isdir(fig_dir):
    os.mkdir(fig_dir)

# %% [markdown]
# We load the metadata (with the subgenre information etc.):

# %%
meta_df = pd.read_excel('../data/metadata_corrected.xlsx')
meta_df = meta_df[meta_df['exclude'] != 'x']
meta_df.sample(10)
# Out:
#                                      id                       title  \
# 267  van_smeinscen_lede                  Van smeinscen lede
# 63   florigout_fragm_l                   Florigout
# 111  loyhier_en_malaert_fragm_a          Loyhier en Malaert
# 86   historie_van_gaver_capeel           Historie van Gaver Capeel
# 168  renout_van_montalbaen_fragm_l       Renout van Montalbaen
# 215  spiegel_historiael__1_3_4_maerlant  Spiegel historiael (P1-P4)
# 211  spiegel_der_sonden                  Spiegel der sonden
# 123  madelgijs_fragm_d                   Madelgijs
# 166  Reinout van Montalbaen              Reinout van Montalbaen
# 240  theophilus                          Theophilus
#
#                  author provenance date_range  genre        subgenre exclude
# 267  NaN                 cdrom-mnl  1300-1400  Epiek  Didactiek       NaN
# 63   NaN                 cdrom-mnl  1375-1400  Epiek  Ridder          NaN
# 111  NaN                 cdrom-mnl  1350-1400  Epiek  Karel           NaN
# 86   NaN                 cdrom-mnl  1500-1520  Epiek  Ridder          NaN
# 168  NaN                 cdrom-mnl  1300-1400  Epiek  Karel           NaN
# 215  Jacob van Maerlant  cdrom-mnl  1300-1325  Epiek  Historiografie  NaN
# 211  NaN                 cdrom-mnl  1440-1460  Epiek  Didactiek       NaN
# 123  NaN                 cdrom-mnl  1340-1360  Epiek  Karel           NaN
# 166  NaN                 CG1        1300-1276  Epiek  Karel           NaN
# 240  NaN                 cdrom-mnl  1400-1420  Epiek  Heiligenleven   NaN

# %% [markdown]
# Next, we redefine the extraction functions from the previous notebooks that we'll need again:

# %%
def get_verse_groups(verses, size=2, intertexts=False):
    for i in range(len(verses) - (size - 1)):
        if not intertexts:
            yield ' / '.join(verses[i : i + size])
        else:
            its = Counter(verses[i : i + size])
            if None in its:
                yield None
            elif len(its) > 1:
                yield 'overlap'
            else:
                yield list(its.keys())[0]

# %%
def parse_xml(fn, rm_interpol=False):
    try:
        tree = lxml.etree.parse(fn)
    except OSError:
        print(f'- Could not load {fn}')
        return None
        
    if rm_interpol:
        for interpolation in tree.xpath("//interpolation"):
            interpolation.getparent().remove(interpolation)
        
    for line_node in tree.iterfind('.//l'):
        try:
            intertext_id = line_node.attrib['intertext']
        except KeyError:
            intertext_id = None
        
        tokens_ = line_node.attrib['tokens'].split()
        lemmas_ = []
        
        lemma_tags = [l.text for l in line_node.iterfind('.//lemma')]
        pos_tags = [p.text for p in line_node.iterfind('.//pos')]
        
        for lemma, pos in zip(lemma_tags, pos_tags):
            for l, p in zip(lemma.split('+'), pos.split('+')):
                    if p == 'n(prop)':
                        lemmas_.append('n(prop)')
                    else:
                        lemmas_.append(l)
    
        yield tokens_, lemmas_, intertext_id

# %%
GROUP_SIZE = 2

titles, tokens, lemmas, intertexts = [], [], [], []

for title, group in tqdm(meta_df.groupby('title')):
    work_tokens, work_lemmas, work_intertexts = [], [], []
    
    for id_ in sorted(group['id']):
        for tok, lem, intertext_id in parse_xml(f'../data/xml/{id_}.xml', rm_interpol=True):
            work_tokens.append(tok)
            work_lemmas.append(lem)
            work_intertexts.append(intertext_id)
    
    verse_tokens = [' '.join(v) for v in work_tokens]
    verse_lemmas = [' '.join(v) for v in work_lemmas]

    verse_group_tokens = list(get_verse_groups(verse_tokens, size=GROUP_SIZE))
    verse_group_lemmas = list(get_verse_groups(verse_lemmas, size=GROUP_SIZE))
    verse_group_intertexts = list(get_verse_groups(work_intertexts, size=GROUP_SIZE, intertexts=True))

    tokens.extend(verse_group_tokens)
    lemmas.extend(verse_group_lemmas)
    intertexts.extend(verse_group_intertexts)
    titles.extend([title] * len(verse_group_lemmas))
# Out:
#   0%|          | 0/205 [00:00<?, ?it/s]/var/folders/6j/pn9nz6b55j3fpdt8gtj50crm0000gn/T/ipykernel_37291/3276123635.py:12: FutureWarning: This search incorrectly ignores the root element, and will be fixed in a future version.  If you rely on the current behaviour, change it to './/l'
#   for line_node in tree.iterfind('//l'):
# 100%|██████████| 205/205 [00:15<00:00, 13.35it/s]

# %% [markdown]
# Now, we can load all the verse groups from all the texts, as well as the associated metdata into a single dataframe:

# %%
df = pd.DataFrame(zip(titles, tokens, lemmas, intertexts), columns=('title', 'tokens', 'lemmas', 'intertext'))

# %% [markdown]
# Finally, we can add the separate column for the lemmas in rhyming position:

# %%
def tokenizer(text):
    return text.replace(' / ', ' ').lower().strip().split()

def add_rhyme_column(df):
    rhyme_words = []
    for lemmas in df['lemmas']:
        rhymes = []
        for verse in lemmas.split(' / '):
            rhymes.append(verse.strip().split()[-1])
        rhyme_words.append(' '.join(rhymes))
    df['rhyme'] = rhyme_words
    return df

# %%
df = add_rhyme_column(df)
df.head()
# Out:
#                     title  \
# 0  AB recht ende averecht
# 1  AB recht ende averecht
# 2  AB recht ende averecht
# 3  AB recht ende averecht
# 4  AB recht ende averecht
#
#                                                                           tokens  \
# 0  Aensiet dese vrouwen hoe si gaen / Besiet hoe haer tuten staen
# 1  Besiet hoe haer tuten staen / Claer dat si hen blanketten
# 2  Claer dat si hen blanketten / Die cleeder soe lanc dat si hen letten
# 3  Die cleeder soe lanc dat si hen letten / Ende sleypen hen nae al op die eerde
# 4  Ende sleypen hen nae al op die eerde / Fi diere vuylder hoverde
#
#                                                                   lemmas  \
# 0  aanzien deze vrouw hoe zij gaan / bezien hoe zij de staan
# 1  bezien hoe zij de staan / klaar dat zij zij n(prop)
# 2  klaar dat zij zij n(prop) / de kleed zo lang dat zij zij letten
# 3  de kleed zo lang dat zij zij letten / en slapen zij na al op de aarde
# 4  en slapen zij na al op de aarde / fi duur vouwer hovaardij
#
#   intertext            rhyme
# 0  None      gaan staan
# 1  None      staan n(prop)
# 2  None      n(prop) letten
# 3  None      letten aarde
# 4  None      aarde hovaardij

# %% [markdown]
# In the previous notebook, these turned out to be the optimal hyperparameters for the retrieval system:

# %%
optim_vs = 9000
optim_rw = 0.1693877551020408
optim_th = 0.4217159759743446

# %%
def batch(iterable, n=1):
    l = iterable.shape[0]
    for ndx in range(0, l, n):
        yield iterable[ndx:min(ndx + n, l)]

def pairwise(AX, BX, batch_size=5000):
    all_distances = None

    for ax in batch(AX, batch_size):
        if all_distances is None:
            all_distances = pairwise_distances(ax, BX, metric='cosine')
        else:
            all_distances = np.append(all_distances,
                                      pairwise_distances(ax, BX, metric='cosine'),
                                      axis=0)
    
    return all_distances

# %%
def retrieve_intertexts(title1, title2, distances, threshold):
    A = df[df['title'] == title1]
    B = df[df['title'] == title2]
    
    intertexts = []
    for idx1, idx2 in np.transpose(np.nonzero(distances < threshold)):
        tokens1 = A.iloc[idx1]['tokens']
        tokens2 = B.iloc[idx2]['tokens']
        distance = distances[idx1, idx2]
        intertexts.append((title1, title2, tokens1, tokens2, distance))
        
    return pd.DataFrame(intertexts, columns=['title1', 'title2', 'tokens1', 'tokens2', 'distance'])

def plot_min_distance_nn(t1, t2, min_dists, threshold, rolling_size=1000):
    mu = min_dists.rolling(rolling_size).mean()
    fig, ax = plt.subplots()
    mu.plot(ax=ax)
    ax.axhline(threshold, ls='--', c='grey')
    ax.set_ylim(0, 1)
    ax.set_xlabel(t1)
    ax.set_ylabel('Distance to NN in ' + t2)
    return ax

# %% [markdown]
# We well restrict the analysis to all narrative texts (in rhyming couplets), or the so-called "Epiek":

# %%
chiv_titles = meta_df[meta_df['genre'] == 'Epiek']['title'].unique()

# %%
vec = TfidfVectorizer(max_features=optim_vs, min_df=2,
                      tokenizer=tokenizer, token_pattern=None).fit(df['lemmas'])

# %% [markdown]
# We will exhaustively combine all texts, but we make sure to only combine two texts once (because our retrieval is non-directional):

# %%
combs = sorted([sorted(comb) for comb in combinations(chiv_titles, 2)])
combs
# Out:
# [['Alexanders geesten', 'Alexiuslegende'],
#  ['Alexanders geesten', 'Anatomie van de mens'],
#  ['Alexanders geesten', 'Arturs doet'],
#  ['Alexanders geesten', 'Aubri de Borgengoen'],
#  ['Alexanders geesten', 'Barlaam en Josaphat'],
#  ['Alexanders geesten', 'Beatrijs'],
#  ['Alexanders geesten', 'Bediedenisse van der missen'],
#  ['Alexanders geesten', 'Beerte metten breden voeten'],
#  ['Alexanders geesten', 'Beginsel der oorlogen van Luyck'],
#  ['Alexanders geesten', 'Boec Exemplaer'],
#  ['Alexanders geesten', 'Boec van den houte'],
#  ['Alexanders geesten', 'Boec vander wraken'],
#  ['Alexanders geesten', 'Boeve van Hamtone'],
#  ['Alexanders geesten', 'Borchgrave van Couchi'],
#  ['Alexanders geesten', 'Borchgravinne van Vergi (1)'],
#  ['Alexanders geesten', 'Borchgravinne van Vergi (2)'],
#  ['Alexanders geesten', 'Boudewijn van Seborch'],
#  ['Alexanders geesten', 'Brabantsche yeesten (B1-5)'],
#  ['Alexanders geesten', 'Brabantsche yeesten (B6)'],
#  ['Alexanders geesten', 'Brabantsche yeesten (B7)'],
#  ['Alexanders geesten', "Chanson d'Aspremont"],
#  ['Alexanders geesten', 'Collectief lunarium I'],
#  ['Alexanders geesten', 'Collectief lunarium II'],
#  ['Alexanders geesten', 'Collectief lunarium III'],
#  ['Alexanders geesten', 'Commentaar op het Hooglied'],
#  ['Alexanders geesten', 'Cyromanchie van den pape van den Hamme'],
#  ['Alexanders geesten', 'Der leken spieghel'],
#  ['Alexanders geesten', 'Der mannen ende vrouwen heimelijcheit'],
#  ['Alexanders geesten', 'Der minnen loep'],
#  ['Alexanders geesten', 'Der naturen bloeme'],
#  ['Alexanders geesten', 'Der vrouwen heimelijcheit'],
#  ['Alexanders geesten', 'Der ystorien bloeme'],
#  ['Alexanders geesten', 'Dietsche Lucidarius'],
#  ['Alexanders geesten', 'Dietsche doctrinale'],
#  ['Alexanders geesten', 'Dystorie van Saladine'],
#  ['Alexanders geesten', 'Enaamse Codex'],
#  ['Alexanders geesten', 'Esopet'],
#  ['Alexanders geesten', 'Expositie vanden viere vingheren ende vanden dume'],
#  ['Alexanders geesten', 'Ferguut'],
#  ['Alexanders geesten', 'Fierabras'],
#  ['Alexanders geesten', 'Flandrijs'],
#  ['Alexanders geesten', 'Florent ende Durant'],
#  ['Alexanders geesten', 'Florigout'],
#  ['Alexanders geesten', 'Florimont'],
#  ['Alexanders geesten', 'Floris ende Blancefloer'],
#  ['Alexanders geesten', 'Flovent'],
#  ['Alexanders geesten', 'Floyris ende Blantseflur'],
#  ['Alexanders geesten', 'Fysionomie'],
#  ['Alexanders geesten', 'Gedicht over de hemeltekenen'],
#  ['Alexanders geesten', 'Geraert van Viane'],
#  ['Alexanders geesten', 'Godevaert metten baerde'],
#  ['Alexanders geesten', 'Godevaerts kintshede'],
#  ['Alexanders geesten', 'Grimbergse oorlog'],
#  ['Alexanders geesten', 'Gwidekijn van Sassen'],
#  ['Alexanders geesten', 'Heymelijchede der heymelijcheit'],
#  ['Alexanders geesten', 'Historie van Gaver Capeel'],
#  ['Alexanders geesten', 'Historie van Troyen'],
#  ['Alexanders geesten', 'Huge van Bordeeus'],
#  ['Alexanders geesten', 'Iechemas'],
#  ['Alexanders geesten', 'Jan Splinters testament'],
#  ['Alexanders geesten', 'Jans teesteye'],
#  ['Alexanders geesten', 'Jonathas ende Rosafiere'],
#  ['Alexanders geesten', 'Karel ende Elegast'],
#  ['Alexanders geesten', 'Korte kroniek van Brabant (korte versie 1)'],
#  ['Alexanders geesten', 'Korte kroniek van Brabant (lange versie)'],
#  ['Alexanders geesten', 'Lanceloet en het hert met de witte voet'],
#  ['Alexanders geesten', 'Lancelot'],
#  ['Alexanders geesten', 'Lantsloot van der Haghedochte'],
#  ['Alexanders geesten', 'Lapidarijs'],
#  ['Alexanders geesten', 'Leven van Sint Trudo (berijming)'],
#  ['Alexanders geesten', 'Limborch'],
#  ['Alexanders geesten', 'Limburgse Aiol'],
#  ['Alexanders geesten', 'Lion van Bourges'],
#  ['Alexanders geesten', 'Loyhier en Malaert'],
#  ['Alexanders geesten', 'Madelgijs'],
#  ['Alexanders geesten', 'Melibeus'],
#  ['Alexanders geesten', 'Merlijn'],
#  ['Alexanders geesten', 'Merlijn-continuatie'],
#  ['Alexanders geesten', 'Moriaen'],
#  ['Alexanders geesten', 'Natuurkunde van het geheelal'],
#  ['Alexanders geesten', 'Nevelingenlied'],
#  ['Alexanders geesten', 'Nieuwe doctrinael'],
#  ['Alexanders geesten', 'Noch die tien ghebode'],
#  ['Alexanders geesten', 'Noch meer van wiven'],
#  ['Alexanders geesten', 'Noch van Salladine'],
#  ['Alexanders geesten', 'O crux lignum triumphale'],
#  ['Alexanders geesten', 'Ogier van Denemarken'],
#  ['Alexanders geesten', 'Ongeïdentificeerd (1)'],
#  ['Alexanders geesten', 'Ongeïdentificeerd (2)'],
#  ['Alexanders geesten', 'Ongeïdentificeerd (3)'],
#  ['Alexanders geesten', 'Ongeïdentificeerd (4)'],
#  ['Alexanders geesten', 'Ongeïdentificeerd (6)'],
#  ['Alexanders geesten', 'Ongeïdentificeerd fragment'],
#  ['Alexanders geesten', 'Ons heren passie'],
#  ['Alexanders geesten', 'Parthonopeus van Bloys'],
#  ['Alexanders geesten', 'Perchevael'],
#  ['Alexanders geesten', 'Queeste van den Grale'],
#  ['Alexanders geesten', 'Reinaerts historie'],
#  ['Alexanders geesten', 'Reinout van Montalbaen'],
#  ['Alexanders geesten', 'Renout van Montalbaen'],
#  ['Alexanders geesten', 'Riddere metter mouwen'],
#  ['Alexanders geesten', 'Rijmbijbel'],
#  ['Alexanders geesten', 'Rijmkroniek van Holland'],
#  ['Alexanders geesten', 'Rijmkroniek van Woeringen'],
#  ['Alexanders geesten', 'Roelantslied'],
#  ['Alexanders geesten', 'Roman der Lorreinen I'],
#  ['Alexanders geesten', 'Roman der Lorreinen II'],
#  ['Alexanders geesten', 'Roman van Antiochië'],
#  ['Alexanders geesten', 'Roman van Caesar'],
#  ['Alexanders geesten', 'Roman van Cassamus (kort)'],
#  ['Alexanders geesten', 'Roman van Cassant'],
#  ['Alexanders geesten', 'Rose'],
#  ['Alexanders geesten', 'Rubben'],
#  ['Alexanders geesten', 'Saladin'],
#  ['Alexanders geesten', 'Schepping'],
#  ['Alexanders geesten', 'Segheliin van Jerusalem'],
#  ['Alexanders geesten', 'Sint Patricius'],
#  ['Alexanders geesten', 'Sint Servaes legende'],
#  ['Alexanders geesten', 'Sinte Franciscus leven'],
#  ['Alexanders geesten',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft"],
#  ['Alexanders geesten', 'Sinte Kerstine'],
#  ['Alexanders geesten', 'Sinte Lutgard'],
#  ['Alexanders geesten', 'Slag van Crecy'],
#  ['Alexanders geesten', 'Speghel der wijsheit'],
#  ['Alexanders geesten', 'Spiegel der jongers'],
#  ['Alexanders geesten', 'Spiegel der sonden'],
#  ['Alexanders geesten', 'Spiegel historiael (P1-P4)'],
#  ['Alexanders geesten', 'Spiegel historiael (P2)'],
#  ['Alexanders geesten', 'Spiegel historiael (P4)'],
#  ['Alexanders geesten', 'Spiegel historiael (P5)'],
#  ['Alexanders geesten', 'Spieghel der menscheliker behoudenesse'],
#  ['Alexanders geesten', 'Theophilus'],
#  ['Alexanders geesten', 'Tien plaghen ende die tien ghebode'],
#  ['Alexanders geesten', 'Torec'],
#  ['Alexanders geesten', 'Tristant'],
#  ['Alexanders geesten', 'Valentijn en Nameloos'],
#  ['Alexanders geesten', 'Van Saladijn'],
#  ['Alexanders geesten', 'Van den VII Vroeden van binnen Rome'],
#  ['Alexanders geesten', 'Van den derden Eduwaert'],
#  ['Alexanders geesten', 'Van den neghen besten (kort)'],
#  ['Alexanders geesten', 'Van den neghen besten (lang)'],
#  ['Alexanders geesten', 'Van den vijf vrouden'],
#  ['Alexanders geesten', 'Van den vos Reynaerde'],
#  ['Alexanders geesten', 'Van der manen zeden'],
#  ['Alexanders geesten', 'Van der wive wonderlijcheit (lange versie)'],
#  ['Alexanders geesten', 'Van ghevene'],
#  ['Alexanders geesten', 'Van sente Brandane'],
#  ['Alexanders geesten', 'Van ses vaerwen ende twaelf outheyden'],
#  ['Alexanders geesten', 'Van smeinscen lede'],
#  ['Alexanders geesten', 'Vande Hertogen ende Heeren van Brabant'],
#  ['Alexanders geesten', 'Vanden levene ons heren'],
#  ['Alexanders geesten', 'Vander rijcheit ende vander doot'],
#  ['Alexanders geesten', 'Vlaamse Aiol'],
#  ['Alexanders geesten', 'Vlaamse Rose'],
#  ['Alexanders geesten', 'Walewein (Penninc)'],
#  ['Alexanders geesten', 'Walewein (Vostaert)'],
#  ['Alexanders geesten', 'Walewein ende Keye'],
#  ['Alexanders geesten', 'Willem van Oringen'],
#  ['Alexanders geesten', 'Wisselau'],
#  ['Alexanders geesten', 'Wrake van Ragisel'],
#  ['Alexiuslegende', 'Anatomie van de mens'],
#  ['Alexiuslegende', 'Arturs doet'],
#  ['Alexiuslegende', 'Aubri de Borgengoen'],
#  ['Alexiuslegende', 'Barlaam en Josaphat'],
#  ['Alexiuslegende', 'Beatrijs'],
#  ['Alexiuslegende', 'Bediedenisse van der missen'],
#  ['Alexiuslegende', 'Beerte metten breden voeten'],
#  ['Alexiuslegende', 'Beginsel der oorlogen van Luyck'],
#  ['Alexiuslegende', 'Boec Exemplaer'],
#  ['Alexiuslegende', 'Boec van den houte'],
#  ['Alexiuslegende', 'Boec vander wraken'],
#  ['Alexiuslegende', 'Boeve van Hamtone'],
#  ['Alexiuslegende', 'Borchgrave van Couchi'],
#  ['Alexiuslegende', 'Borchgravinne van Vergi (1)'],
#  ['Alexiuslegende', 'Borchgravinne van Vergi (2)'],
#  ['Alexiuslegende', 'Boudewijn van Seborch'],
#  ['Alexiuslegende', 'Brabantsche yeesten (B1-5)'],
#  ['Alexiuslegende', 'Brabantsche yeesten (B6)'],
#  ['Alexiuslegende', 'Brabantsche yeesten (B7)'],
#  ['Alexiuslegende', "Chanson d'Aspremont"],
#  ['Alexiuslegende', 'Collectief lunarium I'],
#  ['Alexiuslegende', 'Collectief lunarium II'],
#  ['Alexiuslegende', 'Collectief lunarium III'],
#  ['Alexiuslegende', 'Commentaar op het Hooglied'],
#  ['Alexiuslegende', 'Cyromanchie van den pape van den Hamme'],
#  ['Alexiuslegende', 'Der leken spieghel'],
#  ['Alexiuslegende', 'Der mannen ende vrouwen heimelijcheit'],
#  ['Alexiuslegende', 'Der minnen loep'],
#  ['Alexiuslegende', 'Der naturen bloeme'],
#  ['Alexiuslegende', 'Der vrouwen heimelijcheit'],
#  ['Alexiuslegende', 'Der ystorien bloeme'],
#  ['Alexiuslegende', 'Dietsche Lucidarius'],
#  ['Alexiuslegende', 'Dietsche doctrinale'],
#  ['Alexiuslegende', 'Dystorie van Saladine'],
#  ['Alexiuslegende', 'Enaamse Codex'],
#  ['Alexiuslegende', 'Esopet'],
#  ['Alexiuslegende', 'Expositie vanden viere vingheren ende vanden dume'],
#  ['Alexiuslegende', 'Ferguut'],
#  ['Alexiuslegende', 'Fierabras'],
#  ['Alexiuslegende', 'Flandrijs'],
#  ['Alexiuslegende', 'Florent ende Durant'],
#  ['Alexiuslegende', 'Florigout'],
#  ['Alexiuslegende', 'Florimont'],
#  ['Alexiuslegende', 'Floris ende Blancefloer'],
#  ['Alexiuslegende', 'Flovent'],
#  ['Alexiuslegende', 'Floyris ende Blantseflur'],
#  ['Alexiuslegende', 'Fysionomie'],
#  ['Alexiuslegende', 'Gedicht over de hemeltekenen'],
#  ['Alexiuslegende', 'Geraert van Viane'],
#  ['Alexiuslegende', 'Godevaert metten baerde'],
#  ['Alexiuslegende', 'Godevaerts kintshede'],
#  ['Alexiuslegende', 'Grimbergse oorlog'],
#  ['Alexiuslegende', 'Gwidekijn van Sassen'],
#  ['Alexiuslegende', 'Heymelijchede der heymelijcheit'],
#  ['Alexiuslegende', 'Historie van Gaver Capeel'],
#  ['Alexiuslegende', 'Historie van Troyen'],
#  ['Alexiuslegende', 'Huge van Bordeeus'],
#  ['Alexiuslegende', 'Iechemas'],
#  ['Alexiuslegende', 'Jan Splinters testament'],
#  ['Alexiuslegende', 'Jans teesteye'],
#  ['Alexiuslegende', 'Jonathas ende Rosafiere'],
#  ['Alexiuslegende', 'Karel ende Elegast'],
#  ['Alexiuslegende', 'Korte kroniek van Brabant (korte versie 1)'],
#  ['Alexiuslegende', 'Korte kroniek van Brabant (lange versie)'],
#  ['Alexiuslegende', 'Lanceloet en het hert met de witte voet'],
#  ['Alexiuslegende', 'Lancelot'],
#  ['Alexiuslegende', 'Lantsloot van der Haghedochte'],
#  ['Alexiuslegende', 'Lapidarijs'],
#  ['Alexiuslegende', 'Leven van Sint Trudo (berijming)'],
#  ['Alexiuslegende', 'Limborch'],
#  ['Alexiuslegende', 'Limburgse Aiol'],
#  ['Alexiuslegende', 'Lion van Bourges'],
#  ['Alexiuslegende', 'Loyhier en Malaert'],
#  ['Alexiuslegende', 'Madelgijs'],
#  ['Alexiuslegende', 'Melibeus'],
#  ['Alexiuslegende', 'Merlijn'],
#  ['Alexiuslegende', 'Merlijn-continuatie'],
#  ['Alexiuslegende', 'Moriaen'],
#  ['Alexiuslegende', 'Natuurkunde van het geheelal'],
#  ['Alexiuslegende', 'Nevelingenlied'],
#  ['Alexiuslegende', 'Nieuwe doctrinael'],
#  ['Alexiuslegende', 'Noch die tien ghebode'],
#  ['Alexiuslegende', 'Noch meer van wiven'],
#  ['Alexiuslegende', 'Noch van Salladine'],
#  ['Alexiuslegende', 'O crux lignum triumphale'],
#  ['Alexiuslegende', 'Ogier van Denemarken'],
#  ['Alexiuslegende', 'Ongeïdentificeerd (1)'],
#  ['Alexiuslegende', 'Ongeïdentificeerd (2)'],
#  ['Alexiuslegende', 'Ongeïdentificeerd (3)'],
#  ['Alexiuslegende', 'Ongeïdentificeerd (4)'],
#  ['Alexiuslegende', 'Ongeïdentificeerd (6)'],
#  ['Alexiuslegende', 'Ongeïdentificeerd fragment'],
#  ['Alexiuslegende', 'Ons heren passie'],
#  ['Alexiuslegende', 'Parthonopeus van Bloys'],
#  ['Alexiuslegende', 'Perchevael'],
#  ['Alexiuslegende', 'Queeste van den Grale'],
#  ['Alexiuslegende', 'Reinaerts historie'],
#  ['Alexiuslegende', 'Reinout van Montalbaen'],
#  ['Alexiuslegende', 'Renout van Montalbaen'],
#  ['Alexiuslegende', 'Riddere metter mouwen'],
#  ['Alexiuslegende', 'Rijmbijbel'],
#  ['Alexiuslegende', 'Rijmkroniek van Holland'],
#  ['Alexiuslegende', 'Rijmkroniek van Woeringen'],
#  ['Alexiuslegende', 'Roelantslied'],
#  ['Alexiuslegende', 'Roman der Lorreinen I'],
#  ['Alexiuslegende', 'Roman der Lorreinen II'],
#  ['Alexiuslegende', 'Roman van Antiochië'],
#  ['Alexiuslegende', 'Roman van Caesar'],
#  ['Alexiuslegende', 'Roman van Cassamus (kort)'],
#  ['Alexiuslegende', 'Roman van Cassant'],
#  ['Alexiuslegende', 'Rose'],
#  ['Alexiuslegende', 'Rubben'],
#  ['Alexiuslegende', 'Saladin'],
#  ['Alexiuslegende', 'Schepping'],
#  ['Alexiuslegende', 'Segheliin van Jerusalem'],
#  ['Alexiuslegende', 'Sint Patricius'],
#  ['Alexiuslegende', 'Sint Servaes legende'],
#  ['Alexiuslegende', 'Sinte Franciscus leven'],
#  ['Alexiuslegende',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft"],
#  ['Alexiuslegende', 'Sinte Kerstine'],
#  ['Alexiuslegende', 'Sinte Lutgard'],
#  ['Alexiuslegende', 'Slag van Crecy'],
#  ['Alexiuslegende', 'Speghel der wijsheit'],
#  ['Alexiuslegende', 'Spiegel der jongers'],
#  ['Alexiuslegende', 'Spiegel der sonden'],
#  ['Alexiuslegende', 'Spiegel historiael (P1-P4)'],
#  ['Alexiuslegende', 'Spiegel historiael (P2)'],
#  ['Alexiuslegende', 'Spiegel historiael (P4)'],
#  ['Alexiuslegende', 'Spiegel historiael (P5)'],
#  ['Alexiuslegende', 'Spieghel der menscheliker behoudenesse'],
#  ['Alexiuslegende', 'Theophilus'],
#  ['Alexiuslegende', 'Tien plaghen ende die tien ghebode'],
#  ['Alexiuslegende', 'Torec'],
#  ['Alexiuslegende', 'Tristant'],
#  ['Alexiuslegende', 'Valentijn en Nameloos'],
#  ['Alexiuslegende', 'Van Saladijn'],
#  ['Alexiuslegende', 'Van den VII Vroeden van binnen Rome'],
#  ['Alexiuslegende', 'Van den derden Eduwaert'],
#  ['Alexiuslegende', 'Van den neghen besten (kort)'],
#  ['Alexiuslegende', 'Van den neghen besten (lang)'],
#  ['Alexiuslegende', 'Van den vijf vrouden'],
#  ['Alexiuslegende', 'Van den vos Reynaerde'],
#  ['Alexiuslegende', 'Van der manen zeden'],
#  ['Alexiuslegende', 'Van der wive wonderlijcheit (lange versie)'],
#  ['Alexiuslegende', 'Van ghevene'],
#  ['Alexiuslegende', 'Van sente Brandane'],
#  ['Alexiuslegende', 'Van ses vaerwen ende twaelf outheyden'],
#  ['Alexiuslegende', 'Van smeinscen lede'],
#  ['Alexiuslegende', 'Vande Hertogen ende Heeren van Brabant'],
#  ['Alexiuslegende', 'Vanden levene ons heren'],
#  ['Alexiuslegende', 'Vander rijcheit ende vander doot'],
#  ['Alexiuslegende', 'Vlaamse Aiol'],
#  ['Alexiuslegende', 'Vlaamse Rose'],
#  ['Alexiuslegende', 'Walewein (Penninc)'],
#  ['Alexiuslegende', 'Walewein (Vostaert)'],
#  ['Alexiuslegende', 'Walewein ende Keye'],
#  ['Alexiuslegende', 'Willem van Oringen'],
#  ['Alexiuslegende', 'Wisselau'],
#  ['Alexiuslegende', 'Wrake van Ragisel'],
#  ['Anatomie van de mens', 'Arturs doet'],
#  ['Anatomie van de mens', 'Aubri de Borgengoen'],
#  ['Anatomie van de mens', 'Barlaam en Josaphat'],
#  ['Anatomie van de mens', 'Beatrijs'],
#  ['Anatomie van de mens', 'Bediedenisse van der missen'],
#  ['Anatomie van de mens', 'Beerte metten breden voeten'],
#  ['Anatomie van de mens', 'Beginsel der oorlogen van Luyck'],
#  ['Anatomie van de mens', 'Boec Exemplaer'],
#  ['Anatomie van de mens', 'Boec van den houte'],
#  ['Anatomie van de mens', 'Boec vander wraken'],
#  ['Anatomie van de mens', 'Boeve van Hamtone'],
#  ['Anatomie van de mens', 'Borchgrave van Couchi'],
#  ['Anatomie van de mens', 'Borchgravinne van Vergi (1)'],
#  ['Anatomie van de mens', 'Borchgravinne van Vergi (2)'],
#  ['Anatomie van de mens', 'Boudewijn van Seborch'],
#  ['Anatomie van de mens', 'Brabantsche yeesten (B1-5)'],
#  ['Anatomie van de mens', 'Brabantsche yeesten (B6)'],
#  ['Anatomie van de mens', 'Brabantsche yeesten (B7)'],
#  ['Anatomie van de mens', "Chanson d'Aspremont"],
#  ['Anatomie van de mens', 'Collectief lunarium I'],
#  ['Anatomie van de mens', 'Collectief lunarium II'],
#  ['Anatomie van de mens', 'Collectief lunarium III'],
#  ['Anatomie van de mens', 'Commentaar op het Hooglied'],
#  ['Anatomie van de mens', 'Cyromanchie van den pape van den Hamme'],
#  ['Anatomie van de mens', 'Der leken spieghel'],
#  ['Anatomie van de mens', 'Der mannen ende vrouwen heimelijcheit'],
#  ['Anatomie van de mens', 'Der minnen loep'],
#  ['Anatomie van de mens', 'Der naturen bloeme'],
#  ['Anatomie van de mens', 'Der vrouwen heimelijcheit'],
#  ['Anatomie van de mens', 'Der ystorien bloeme'],
#  ['Anatomie van de mens', 'Dietsche Lucidarius'],
#  ['Anatomie van de mens', 'Dietsche doctrinale'],
#  ['Anatomie van de mens', 'Dystorie van Saladine'],
#  ['Anatomie van de mens', 'Enaamse Codex'],
#  ['Anatomie van de mens', 'Esopet'],
#  ['Anatomie van de mens', 'Expositie vanden viere vingheren ende vanden dume'],
#  ['Anatomie van de mens', 'Ferguut'],
#  ['Anatomie van de mens', 'Fierabras'],
#  ['Anatomie van de mens', 'Flandrijs'],
#  ['Anatomie van de mens', 'Florent ende Durant'],
#  ['Anatomie van de mens', 'Florigout'],
#  ['Anatomie van de mens', 'Florimont'],
#  ['Anatomie van de mens', 'Floris ende Blancefloer'],
#  ['Anatomie van de mens', 'Flovent'],
#  ['Anatomie van de mens', 'Floyris ende Blantseflur'],
#  ['Anatomie van de mens', 'Fysionomie'],
#  ['Anatomie van de mens', 'Gedicht over de hemeltekenen'],
#  ['Anatomie van de mens', 'Geraert van Viane'],
#  ['Anatomie van de mens', 'Godevaert metten baerde'],
#  ['Anatomie van de mens', 'Godevaerts kintshede'],
#  ['Anatomie van de mens', 'Grimbergse oorlog'],
#  ['Anatomie van de mens', 'Gwidekijn van Sassen'],
#  ['Anatomie van de mens', 'Heymelijchede der heymelijcheit'],
#  ['Anatomie van de mens', 'Historie van Gaver Capeel'],
#  ['Anatomie van de mens', 'Historie van Troyen'],
#  ['Anatomie van de mens', 'Huge van Bordeeus'],
#  ['Anatomie van de mens', 'Iechemas'],
#  ['Anatomie van de mens', 'Jan Splinters testament'],
#  ['Anatomie van de mens', 'Jans teesteye'],
#  ['Anatomie van de mens', 'Jonathas ende Rosafiere'],
#  ['Anatomie van de mens', 'Karel ende Elegast'],
#  ['Anatomie van de mens', 'Korte kroniek van Brabant (korte versie 1)'],
#  ['Anatomie van de mens', 'Korte kroniek van Brabant (lange versie)'],
#  ['Anatomie van de mens', 'Lanceloet en het hert met de witte voet'],
#  ['Anatomie van de mens', 'Lancelot'],
#  ['Anatomie van de mens', 'Lantsloot van der Haghedochte'],
#  ['Anatomie van de mens', 'Lapidarijs'],
#  ['Anatomie van de mens', 'Leven van Sint Trudo (berijming)'],
#  ['Anatomie van de mens', 'Limborch'],
#  ['Anatomie van de mens', 'Limburgse Aiol'],
#  ['Anatomie van de mens', 'Lion van Bourges'],
#  ['Anatomie van de mens', 'Loyhier en Malaert'],
#  ['Anatomie van de mens', 'Madelgijs'],
#  ['Anatomie van de mens', 'Melibeus'],
#  ['Anatomie van de mens', 'Merlijn'],
#  ['Anatomie van de mens', 'Merlijn-continuatie'],
#  ['Anatomie van de mens', 'Moriaen'],
#  ['Anatomie van de mens', 'Natuurkunde van het geheelal'],
#  ['Anatomie van de mens', 'Nevelingenlied'],
#  ['Anatomie van de mens', 'Nieuwe doctrinael'],
#  ['Anatomie van de mens', 'Noch die tien ghebode'],
#  ['Anatomie van de mens', 'Noch meer van wiven'],
#  ['Anatomie van de mens', 'Noch van Salladine'],
#  ['Anatomie van de mens', 'O crux lignum triumphale'],
#  ['Anatomie van de mens', 'Ogier van Denemarken'],
#  ['Anatomie van de mens', 'Ongeïdentificeerd (1)'],
#  ['Anatomie van de mens', 'Ongeïdentificeerd (2)'],
#  ['Anatomie van de mens', 'Ongeïdentificeerd (3)'],
#  ['Anatomie van de mens', 'Ongeïdentificeerd (4)'],
#  ['Anatomie van de mens', 'Ongeïdentificeerd (6)'],
#  ['Anatomie van de mens', 'Ongeïdentificeerd fragment'],
#  ['Anatomie van de mens', 'Ons heren passie'],
#  ['Anatomie van de mens', 'Parthonopeus van Bloys'],
#  ['Anatomie van de mens', 'Perchevael'],
#  ['Anatomie van de mens', 'Queeste van den Grale'],
#  ['Anatomie van de mens', 'Reinaerts historie'],
#  ['Anatomie van de mens', 'Reinout van Montalbaen'],
#  ['Anatomie van de mens', 'Renout van Montalbaen'],
#  ['Anatomie van de mens', 'Riddere metter mouwen'],
#  ['Anatomie van de mens', 'Rijmbijbel'],
#  ['Anatomie van de mens', 'Rijmkroniek van Holland'],
#  ['Anatomie van de mens', 'Rijmkroniek van Woeringen'],
#  ['Anatomie van de mens', 'Roelantslied'],
#  ['Anatomie van de mens', 'Roman der Lorreinen I'],
#  ['Anatomie van de mens', 'Roman der Lorreinen II'],
#  ['Anatomie van de mens', 'Roman van Antiochië'],
#  ['Anatomie van de mens', 'Roman van Caesar'],
#  ['Anatomie van de mens', 'Roman van Cassamus (kort)'],
#  ['Anatomie van de mens', 'Roman van Cassant'],
#  ['Anatomie van de mens', 'Rose'],
#  ['Anatomie van de mens', 'Rubben'],
#  ['Anatomie van de mens', 'Saladin'],
#  ['Anatomie van de mens', 'Schepping'],
#  ['Anatomie van de mens', 'Segheliin van Jerusalem'],
#  ['Anatomie van de mens', 'Sint Patricius'],
#  ['Anatomie van de mens', 'Sint Servaes legende'],
#  ['Anatomie van de mens', 'Sinte Franciscus leven'],
#  ['Anatomie van de mens',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft"],
#  ['Anatomie van de mens', 'Sinte Kerstine'],
#  ['Anatomie van de mens', 'Sinte Lutgard'],
#  ['Anatomie van de mens', 'Slag van Crecy'],
#  ['Anatomie van de mens', 'Speghel der wijsheit'],
#  ['Anatomie van de mens', 'Spiegel der jongers'],
#  ['Anatomie van de mens', 'Spiegel der sonden'],
#  ['Anatomie van de mens', 'Spiegel historiael (P1-P4)'],
#  ['Anatomie van de mens', 'Spiegel historiael (P2)'],
#  ['Anatomie van de mens', 'Spiegel historiael (P4)'],
#  ['Anatomie van de mens', 'Spiegel historiael (P5)'],
#  ['Anatomie van de mens', 'Spieghel der menscheliker behoudenesse'],
#  ['Anatomie van de mens', 'Theophilus'],
#  ['Anatomie van de mens', 'Tien plaghen ende die tien ghebode'],
#  ['Anatomie van de mens', 'Torec'],
#  ['Anatomie van de mens', 'Tristant'],
#  ['Anatomie van de mens', 'Valentijn en Nameloos'],
#  ['Anatomie van de mens', 'Van Saladijn'],
#  ['Anatomie van de mens', 'Van den VII Vroeden van binnen Rome'],
#  ['Anatomie van de mens', 'Van den derden Eduwaert'],
#  ['Anatomie van de mens', 'Van den neghen besten (kort)'],
#  ['Anatomie van de mens', 'Van den neghen besten (lang)'],
#  ['Anatomie van de mens', 'Van den vijf vrouden'],
#  ['Anatomie van de mens', 'Van den vos Reynaerde'],
#  ['Anatomie van de mens', 'Van der manen zeden'],
#  ['Anatomie van de mens', 'Van der wive wonderlijcheit (lange versie)'],
#  ['Anatomie van de mens', 'Van ghevene'],
#  ['Anatomie van de mens', 'Van sente Brandane'],
#  ['Anatomie van de mens', 'Van ses vaerwen ende twaelf outheyden'],
#  ['Anatomie van de mens', 'Van smeinscen lede'],
#  ['Anatomie van de mens', 'Vande Hertogen ende Heeren van Brabant'],
#  ['Anatomie van de mens', 'Vanden levene ons heren'],
#  ['Anatomie van de mens', 'Vander rijcheit ende vander doot'],
#  ['Anatomie van de mens', 'Vlaamse Aiol'],
#  ['Anatomie van de mens', 'Vlaamse Rose'],
#  ['Anatomie van de mens', 'Walewein (Penninc)'],
#  ['Anatomie van de mens', 'Walewein (Vostaert)'],
#  ['Anatomie van de mens', 'Walewein ende Keye'],
#  ['Anatomie van de mens', 'Willem van Oringen'],
#  ['Anatomie van de mens', 'Wisselau'],
#  ['Anatomie van de mens', 'Wrake van Ragisel'],
#  ['Arturs doet', 'Aubri de Borgengoen'],
#  ['Arturs doet', 'Barlaam en Josaphat'],
#  ['Arturs doet', 'Beatrijs'],
#  ['Arturs doet', 'Bediedenisse van der missen'],
#  ['Arturs doet', 'Beerte metten breden voeten'],
#  ['Arturs doet', 'Beginsel der oorlogen van Luyck'],
#  ['Arturs doet', 'Boec Exemplaer'],
#  ['Arturs doet', 'Boec van den houte'],
#  ['Arturs doet', 'Boec vander wraken'],
#  ['Arturs doet', 'Boeve van Hamtone'],
#  ['Arturs doet', 'Borchgrave van Couchi'],
#  ['Arturs doet', 'Borchgravinne van Vergi (1)'],
#  ['Arturs doet', 'Borchgravinne van Vergi (2)'],
#  ['Arturs doet', 'Boudewijn van Seborch'],
#  ['Arturs doet', 'Brabantsche yeesten (B1-5)'],
#  ['Arturs doet', 'Brabantsche yeesten (B6)'],
#  ['Arturs doet', 'Brabantsche yeesten (B7)'],
#  ['Arturs doet', "Chanson d'Aspremont"],
#  ['Arturs doet', 'Collectief lunarium I'],
#  ['Arturs doet', 'Collectief lunarium II'],
#  ['Arturs doet', 'Collectief lunarium III'],
#  ['Arturs doet', 'Commentaar op het Hooglied'],
#  ['Arturs doet', 'Cyromanchie van den pape van den Hamme'],
#  ['Arturs doet', 'Der leken spieghel'],
#  ['Arturs doet', 'Der mannen ende vrouwen heimelijcheit'],
#  ['Arturs doet', 'Der minnen loep'],
#  ['Arturs doet', 'Der naturen bloeme'],
#  ['Arturs doet', 'Der vrouwen heimelijcheit'],
#  ['Arturs doet', 'Der ystorien bloeme'],
#  ['Arturs doet', 'Dietsche Lucidarius'],
#  ['Arturs doet', 'Dietsche doctrinale'],
#  ['Arturs doet', 'Dystorie van Saladine'],
#  ['Arturs doet', 'Enaamse Codex'],
#  ['Arturs doet', 'Esopet'],
#  ['Arturs doet', 'Expositie vanden viere vingheren ende vanden dume'],
#  ['Arturs doet', 'Ferguut'],
#  ['Arturs doet', 'Fierabras'],
#  ['Arturs doet', 'Flandrijs'],
#  ['Arturs doet', 'Florent ende Durant'],
#  ['Arturs doet', 'Florigout'],
#  ['Arturs doet', 'Florimont'],
#  ['Arturs doet', 'Floris ende Blancefloer'],
#  ['Arturs doet', 'Flovent'],
#  ['Arturs doet', 'Floyris ende Blantseflur'],
#  ['Arturs doet', 'Fysionomie'],
#  ['Arturs doet', 'Gedicht over de hemeltekenen'],
#  ['Arturs doet', 'Geraert van Viane'],
#  ['Arturs doet', 'Godevaert metten baerde'],
#  ['Arturs doet', 'Godevaerts kintshede'],
#  ['Arturs doet', 'Grimbergse oorlog'],
#  ['Arturs doet', 'Gwidekijn van Sassen'],
#  ['Arturs doet', 'Heymelijchede der heymelijcheit'],
#  ['Arturs doet', 'Historie van Gaver Capeel'],
#  ['Arturs doet', 'Historie van Troyen'],
#  ['Arturs doet', 'Huge van Bordeeus'],
#  ['Arturs doet', 'Iechemas'],
#  ['Arturs doet', 'Jan Splinters testament'],
#  ['Arturs doet', 'Jans teesteye'],
#  ['Arturs doet', 'Jonathas ende Rosafiere'],
#  ['Arturs doet', 'Karel ende Elegast'],
#  ['Arturs doet', 'Korte kroniek van Brabant (korte versie 1)'],
#  ['Arturs doet', 'Korte kroniek van Brabant (lange versie)'],
#  ['Arturs doet', 'Lanceloet en het hert met de witte voet'],
#  ['Arturs doet', 'Lancelot'],
#  ['Arturs doet', 'Lantsloot van der Haghedochte'],
#  ['Arturs doet', 'Lapidarijs'],
#  ['Arturs doet', 'Leven van Sint Trudo (berijming)'],
#  ['Arturs doet', 'Limborch'],
#  ['Arturs doet', 'Limburgse Aiol'],
#  ['Arturs doet', 'Lion van Bourges'],
#  ['Arturs doet', 'Loyhier en Malaert'],
#  ['Arturs doet', 'Madelgijs'],
#  ['Arturs doet', 'Melibeus'],
#  ['Arturs doet', 'Merlijn'],
#  ['Arturs doet', 'Merlijn-continuatie'],
#  ['Arturs doet', 'Moriaen'],
#  ['Arturs doet', 'Natuurkunde van het geheelal'],
#  ['Arturs doet', 'Nevelingenlied'],
#  ['Arturs doet', 'Nieuwe doctrinael'],
#  ['Arturs doet', 'Noch die tien ghebode'],
#  ['Arturs doet', 'Noch meer van wiven'],
#  ['Arturs doet', 'Noch van Salladine'],
#  ['Arturs doet', 'O crux lignum triumphale'],
#  ['Arturs doet', 'Ogier van Denemarken'],
#  ['Arturs doet', 'Ongeïdentificeerd (1)'],
#  ['Arturs doet', 'Ongeïdentificeerd (2)'],
#  ['Arturs doet', 'Ongeïdentificeerd (3)'],
#  ['Arturs doet', 'Ongeïdentificeerd (4)'],
#  ['Arturs doet', 'Ongeïdentificeerd (6)'],
#  ['Arturs doet', 'Ongeïdentificeerd fragment'],
#  ['Arturs doet', 'Ons heren passie'],
#  ['Arturs doet', 'Parthonopeus van Bloys'],
#  ['Arturs doet', 'Perchevael'],
#  ['Arturs doet', 'Queeste van den Grale'],
#  ['Arturs doet', 'Reinaerts historie'],
#  ['Arturs doet', 'Reinout van Montalbaen'],
#  ['Arturs doet', 'Renout van Montalbaen'],
#  ['Arturs doet', 'Riddere metter mouwen'],
#  ['Arturs doet', 'Rijmbijbel'],
#  ['Arturs doet', 'Rijmkroniek van Holland'],
#  ['Arturs doet', 'Rijmkroniek van Woeringen'],
#  ['Arturs doet', 'Roelantslied'],
#  ['Arturs doet', 'Roman der Lorreinen I'],
#  ['Arturs doet', 'Roman der Lorreinen II'],
#  ['Arturs doet', 'Roman van Antiochië'],
#  ['Arturs doet', 'Roman van Caesar'],
#  ['Arturs doet', 'Roman van Cassamus (kort)'],
#  ['Arturs doet', 'Roman van Cassant'],
#  ['Arturs doet', 'Rose'],
#  ['Arturs doet', 'Rubben'],
#  ['Arturs doet', 'Saladin'],
#  ['Arturs doet', 'Schepping'],
#  ['Arturs doet', 'Segheliin van Jerusalem'],
#  ['Arturs doet', 'Sint Patricius'],
#  ['Arturs doet', 'Sint Servaes legende'],
#  ['Arturs doet', 'Sinte Franciscus leven'],
#  ['Arturs doet',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft"],
#  ['Arturs doet', 'Sinte Kerstine'],
#  ['Arturs doet', 'Sinte Lutgard'],
#  ['Arturs doet', 'Slag van Crecy'],
#  ['Arturs doet', 'Speghel der wijsheit'],
#  ['Arturs doet', 'Spiegel der jongers'],
#  ['Arturs doet', 'Spiegel der sonden'],
#  ['Arturs doet', 'Spiegel historiael (P1-P4)'],
#  ['Arturs doet', 'Spiegel historiael (P2)'],
#  ['Arturs doet', 'Spiegel historiael (P4)'],
#  ['Arturs doet', 'Spiegel historiael (P5)'],
#  ['Arturs doet', 'Spieghel der menscheliker behoudenesse'],
#  ['Arturs doet', 'Theophilus'],
#  ['Arturs doet', 'Tien plaghen ende die tien ghebode'],
#  ['Arturs doet', 'Torec'],
#  ['Arturs doet', 'Tristant'],
#  ['Arturs doet', 'Valentijn en Nameloos'],
#  ['Arturs doet', 'Van Saladijn'],
#  ['Arturs doet', 'Van den VII Vroeden van binnen Rome'],
#  ['Arturs doet', 'Van den derden Eduwaert'],
#  ['Arturs doet', 'Van den neghen besten (kort)'],
#  ['Arturs doet', 'Van den neghen besten (lang)'],
#  ['Arturs doet', 'Van den vijf vrouden'],
#  ['Arturs doet', 'Van den vos Reynaerde'],
#  ['Arturs doet', 'Van der manen zeden'],
#  ['Arturs doet', 'Van der wive wonderlijcheit (lange versie)'],
#  ['Arturs doet', 'Van ghevene'],
#  ['Arturs doet', 'Van sente Brandane'],
#  ['Arturs doet', 'Van ses vaerwen ende twaelf outheyden'],
#  ['Arturs doet', 'Van smeinscen lede'],
#  ['Arturs doet', 'Vande Hertogen ende Heeren van Brabant'],
#  ['Arturs doet', 'Vanden levene ons heren'],
#  ['Arturs doet', 'Vander rijcheit ende vander doot'],
#  ['Arturs doet', 'Vlaamse Aiol'],
#  ['Arturs doet', 'Vlaamse Rose'],
#  ['Arturs doet', 'Walewein (Penninc)'],
#  ['Arturs doet', 'Walewein (Vostaert)'],
#  ['Arturs doet', 'Walewein ende Keye'],
#  ['Arturs doet', 'Willem van Oringen'],
#  ['Arturs doet', 'Wisselau'],
#  ['Arturs doet', 'Wrake van Ragisel'],
#  ['Aubri de Borgengoen', 'Barlaam en Josaphat'],
#  ['Aubri de Borgengoen', 'Beatrijs'],
#  ['Aubri de Borgengoen', 'Bediedenisse van der missen'],
#  ['Aubri de Borgengoen', 'Beerte metten breden voeten'],
#  ['Aubri de Borgengoen', 'Beginsel der oorlogen van Luyck'],
#  ['Aubri de Borgengoen', 'Boec Exemplaer'],
#  ['Aubri de Borgengoen', 'Boec van den houte'],
#  ['Aubri de Borgengoen', 'Boec vander wraken'],
#  ['Aubri de Borgengoen', 'Boeve van Hamtone'],
#  ['Aubri de Borgengoen', 'Borchgrave van Couchi'],
#  ['Aubri de Borgengoen', 'Borchgravinne van Vergi (1)'],
#  ['Aubri de Borgengoen', 'Borchgravinne van Vergi (2)'],
#  ['Aubri de Borgengoen', 'Boudewijn van Seborch'],
#  ['Aubri de Borgengoen', 'Brabantsche yeesten (B1-5)'],
#  ['Aubri de Borgengoen', 'Brabantsche yeesten (B6)'],
#  ['Aubri de Borgengoen', 'Brabantsche yeesten (B7)'],
#  ['Aubri de Borgengoen', "Chanson d'Aspremont"],
#  ['Aubri de Borgengoen', 'Collectief lunarium I'],
#  ['Aubri de Borgengoen', 'Collectief lunarium II'],
#  ['Aubri de Borgengoen', 'Collectief lunarium III'],
#  ['Aubri de Borgengoen', 'Commentaar op het Hooglied'],
#  ['Aubri de Borgengoen', 'Cyromanchie van den pape van den Hamme'],
#  ['Aubri de Borgengoen', 'Der leken spieghel'],
#  ['Aubri de Borgengoen', 'Der mannen ende vrouwen heimelijcheit'],
#  ['Aubri de Borgengoen', 'Der minnen loep'],
#  ['Aubri de Borgengoen', 'Der naturen bloeme'],
#  ['Aubri de Borgengoen', 'Der vrouwen heimelijcheit'],
#  ['Aubri de Borgengoen', 'Der ystorien bloeme'],
#  ['Aubri de Borgengoen', 'Dietsche Lucidarius'],
#  ['Aubri de Borgengoen', 'Dietsche doctrinale'],
#  ['Aubri de Borgengoen', 'Dystorie van Saladine'],
#  ['Aubri de Borgengoen', 'Enaamse Codex'],
#  ['Aubri de Borgengoen', 'Esopet'],
#  ['Aubri de Borgengoen', 'Expositie vanden viere vingheren ende vanden dume'],
#  ['Aubri de Borgengoen', 'Ferguut'],
#  ['Aubri de Borgengoen', 'Fierabras'],
#  ['Aubri de Borgengoen', 'Flandrijs'],
#  ['Aubri de Borgengoen', 'Florent ende Durant'],
#  ['Aubri de Borgengoen', 'Florigout'],
#  ['Aubri de Borgengoen', 'Florimont'],
#  ['Aubri de Borgengoen', 'Floris ende Blancefloer'],
#  ['Aubri de Borgengoen', 'Flovent'],
#  ['Aubri de Borgengoen', 'Floyris ende Blantseflur'],
#  ['Aubri de Borgengoen', 'Fysionomie'],
#  ['Aubri de Borgengoen', 'Gedicht over de hemeltekenen'],
#  ['Aubri de Borgengoen', 'Geraert van Viane'],
#  ['Aubri de Borgengoen', 'Godevaert metten baerde'],
#  ['Aubri de Borgengoen', 'Godevaerts kintshede'],
#  ['Aubri de Borgengoen', 'Grimbergse oorlog'],
#  ['Aubri de Borgengoen', 'Gwidekijn van Sassen'],
#  ['Aubri de Borgengoen', 'Heymelijchede der heymelijcheit'],
#  ['Aubri de Borgengoen', 'Historie van Gaver Capeel'],
#  ['Aubri de Borgengoen', 'Historie van Troyen'],
#  ['Aubri de Borgengoen', 'Huge van Bordeeus'],
#  ['Aubri de Borgengoen', 'Iechemas'],
#  ['Aubri de Borgengoen', 'Jan Splinters testament'],
#  ['Aubri de Borgengoen', 'Jans teesteye'],
#  ['Aubri de Borgengoen', 'Jonathas ende Rosafiere'],
#  ['Aubri de Borgengoen', 'Karel ende Elegast'],
#  ['Aubri de Borgengoen', 'Korte kroniek van Brabant (korte versie 1)'],
#  ['Aubri de Borgengoen', 'Korte kroniek van Brabant (lange versie)'],
#  ['Aubri de Borgengoen', 'Lanceloet en het hert met de witte voet'],
#  ['Aubri de Borgengoen', 'Lancelot'],
#  ['Aubri de Borgengoen', 'Lantsloot van der Haghedochte'],
#  ['Aubri de Borgengoen', 'Lapidarijs'],
#  ['Aubri de Borgengoen', 'Leven van Sint Trudo (berijming)'],
#  ['Aubri de Borgengoen', 'Limborch'],
#  ['Aubri de Borgengoen', 'Limburgse Aiol'],
#  ['Aubri de Borgengoen', 'Lion van Bourges'],
#  ['Aubri de Borgengoen', 'Loyhier en Malaert'],
#  ['Aubri de Borgengoen', 'Madelgijs'],
#  ['Aubri de Borgengoen', 'Melibeus'],
#  ['Aubri de Borgengoen', 'Merlijn'],
#  ['Aubri de Borgengoen', 'Merlijn-continuatie'],
#  ['Aubri de Borgengoen', 'Moriaen'],
#  ['Aubri de Borgengoen', 'Natuurkunde van het geheelal'],
#  ['Aubri de Borgengoen', 'Nevelingenlied'],
#  ['Aubri de Borgengoen', 'Nieuwe doctrinael'],
#  ['Aubri de Borgengoen', 'Noch die tien ghebode'],
#  ['Aubri de Borgengoen', 'Noch meer van wiven'],
#  ['Aubri de Borgengoen', 'Noch van Salladine'],
#  ['Aubri de Borgengoen', 'O crux lignum triumphale'],
#  ['Aubri de Borgengoen', 'Ogier van Denemarken'],
#  ['Aubri de Borgengoen', 'Ongeïdentificeerd (1)'],
#  ['Aubri de Borgengoen', 'Ongeïdentificeerd (2)'],
#  ['Aubri de Borgengoen', 'Ongeïdentificeerd (3)'],
#  ['Aubri de Borgengoen', 'Ongeïdentificeerd (4)'],
#  ['Aubri de Borgengoen', 'Ongeïdentificeerd (6)'],
#  ['Aubri de Borgengoen', 'Ongeïdentificeerd fragment'],
#  ['Aubri de Borgengoen', 'Ons heren passie'],
#  ['Aubri de Borgengoen', 'Parthonopeus van Bloys'],
#  ['Aubri de Borgengoen', 'Perchevael'],
#  ['Aubri de Borgengoen', 'Queeste van den Grale'],
#  ['Aubri de Borgengoen', 'Reinaerts historie'],
#  ['Aubri de Borgengoen', 'Reinout van Montalbaen'],
#  ['Aubri de Borgengoen', 'Renout van Montalbaen'],
#  ['Aubri de Borgengoen', 'Riddere metter mouwen'],
#  ['Aubri de Borgengoen', 'Rijmbijbel'],
#  ['Aubri de Borgengoen', 'Rijmkroniek van Holland'],
#  ['Aubri de Borgengoen', 'Rijmkroniek van Woeringen'],
#  ['Aubri de Borgengoen', 'Roelantslied'],
#  ['Aubri de Borgengoen', 'Roman der Lorreinen I'],
#  ['Aubri de Borgengoen', 'Roman der Lorreinen II'],
#  ['Aubri de Borgengoen', 'Roman van Antiochië'],
#  ['Aubri de Borgengoen', 'Roman van Caesar'],
#  ['Aubri de Borgengoen', 'Roman van Cassamus (kort)'],
#  ['Aubri de Borgengoen', 'Roman van Cassant'],
#  ['Aubri de Borgengoen', 'Rose'],
#  ['Aubri de Borgengoen', 'Rubben'],
#  ['Aubri de Borgengoen', 'Saladin'],
#  ['Aubri de Borgengoen', 'Schepping'],
#  ['Aubri de Borgengoen', 'Segheliin van Jerusalem'],
#  ['Aubri de Borgengoen', 'Sint Patricius'],
#  ['Aubri de Borgengoen', 'Sint Servaes legende'],
#  ['Aubri de Borgengoen', 'Sinte Franciscus leven'],
#  ['Aubri de Borgengoen',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft"],
#  ['Aubri de Borgengoen', 'Sinte Kerstine'],
#  ['Aubri de Borgengoen', 'Sinte Lutgard'],
#  ['Aubri de Borgengoen', 'Slag van Crecy'],
#  ['Aubri de Borgengoen', 'Speghel der wijsheit'],
#  ['Aubri de Borgengoen', 'Spiegel der jongers'],
#  ['Aubri de Borgengoen', 'Spiegel der sonden'],
#  ['Aubri de Borgengoen', 'Spiegel historiael (P1-P4)'],
#  ['Aubri de Borgengoen', 'Spiegel historiael (P2)'],
#  ['Aubri de Borgengoen', 'Spiegel historiael (P4)'],
#  ['Aubri de Borgengoen', 'Spiegel historiael (P5)'],
#  ['Aubri de Borgengoen', 'Spieghel der menscheliker behoudenesse'],
#  ['Aubri de Borgengoen', 'Theophilus'],
#  ['Aubri de Borgengoen', 'Tien plaghen ende die tien ghebode'],
#  ['Aubri de Borgengoen', 'Torec'],
#  ['Aubri de Borgengoen', 'Tristant'],
#  ['Aubri de Borgengoen', 'Valentijn en Nameloos'],
#  ['Aubri de Borgengoen', 'Van Saladijn'],
#  ['Aubri de Borgengoen', 'Van den VII Vroeden van binnen Rome'],
#  ['Aubri de Borgengoen', 'Van den derden Eduwaert'],
#  ['Aubri de Borgengoen', 'Van den neghen besten (kort)'],
#  ['Aubri de Borgengoen', 'Van den neghen besten (lang)'],
#  ['Aubri de Borgengoen', 'Van den vijf vrouden'],
#  ['Aubri de Borgengoen', 'Van den vos Reynaerde'],
#  ['Aubri de Borgengoen', 'Van der manen zeden'],
#  ['Aubri de Borgengoen', 'Van der wive wonderlijcheit (lange versie)'],
#  ['Aubri de Borgengoen', 'Van ghevene'],
#  ['Aubri de Borgengoen', 'Van sente Brandane'],
#  ['Aubri de Borgengoen', 'Van ses vaerwen ende twaelf outheyden'],
#  ['Aubri de Borgengoen', 'Van smeinscen lede'],
#  ['Aubri de Borgengoen', 'Vande Hertogen ende Heeren van Brabant'],
#  ['Aubri de Borgengoen', 'Vanden levene ons heren'],
#  ['Aubri de Borgengoen', 'Vander rijcheit ende vander doot'],
#  ['Aubri de Borgengoen', 'Vlaamse Aiol'],
#  ['Aubri de Borgengoen', 'Vlaamse Rose'],
#  ['Aubri de Borgengoen', 'Walewein (Penninc)'],
#  ['Aubri de Borgengoen', 'Walewein (Vostaert)'],
#  ['Aubri de Borgengoen', 'Walewein ende Keye'],
#  ['Aubri de Borgengoen', 'Willem van Oringen'],
#  ['Aubri de Borgengoen', 'Wisselau'],
#  ['Aubri de Borgengoen', 'Wrake van Ragisel'],
#  ['Barlaam en Josaphat', 'Beatrijs'],
#  ['Barlaam en Josaphat', 'Bediedenisse van der missen'],
#  ['Barlaam en Josaphat', 'Beerte metten breden voeten'],
#  ['Barlaam en Josaphat', 'Beginsel der oorlogen van Luyck'],
#  ['Barlaam en Josaphat', 'Boec Exemplaer'],
#  ['Barlaam en Josaphat', 'Boec van den houte'],
#  ['Barlaam en Josaphat', 'Boec vander wraken'],
#  ['Barlaam en Josaphat', 'Boeve van Hamtone'],
#  ['Barlaam en Josaphat', 'Borchgrave van Couchi'],
#  ['Barlaam en Josaphat', 'Borchgravinne van Vergi (1)'],
#  ['Barlaam en Josaphat', 'Borchgravinne van Vergi (2)'],
#  ['Barlaam en Josaphat', 'Boudewijn van Seborch'],
#  ['Barlaam en Josaphat', 'Brabantsche yeesten (B1-5)'],
#  ['Barlaam en Josaphat', 'Brabantsche yeesten (B6)'],
#  ['Barlaam en Josaphat', 'Brabantsche yeesten (B7)'],
#  ['Barlaam en Josaphat', "Chanson d'Aspremont"],
#  ['Barlaam en Josaphat', 'Collectief lunarium I'],
#  ['Barlaam en Josaphat', 'Collectief lunarium II'],
#  ['Barlaam en Josaphat', 'Collectief lunarium III'],
#  ['Barlaam en Josaphat', 'Commentaar op het Hooglied'],
#  ['Barlaam en Josaphat', 'Cyromanchie van den pape van den Hamme'],
#  ['Barlaam en Josaphat', 'Der leken spieghel'],
#  ['Barlaam en Josaphat', 'Der mannen ende vrouwen heimelijcheit'],
#  ['Barlaam en Josaphat', 'Der minnen loep'],
#  ['Barlaam en Josaphat', 'Der naturen bloeme'],
#  ['Barlaam en Josaphat', 'Der vrouwen heimelijcheit'],
#  ['Barlaam en Josaphat', 'Der ystorien bloeme'],
#  ['Barlaam en Josaphat', 'Dietsche Lucidarius'],
#  ['Barlaam en Josaphat', 'Dietsche doctrinale'],
#  ['Barlaam en Josaphat', 'Dystorie van Saladine'],
#  ['Barlaam en Josaphat', 'Enaamse Codex'],
#  ['Barlaam en Josaphat', 'Esopet'],
#  ['Barlaam en Josaphat', 'Expositie vanden viere vingheren ende vanden dume'],
#  ['Barlaam en Josaphat', 'Ferguut'],
#  ['Barlaam en Josaphat', 'Fierabras'],
#  ['Barlaam en Josaphat', 'Flandrijs'],
#  ['Barlaam en Josaphat', 'Florent ende Durant'],
#  ['Barlaam en Josaphat', 'Florigout'],
#  ['Barlaam en Josaphat', 'Florimont'],
#  ['Barlaam en Josaphat', 'Floris ende Blancefloer'],
#  ['Barlaam en Josaphat', 'Flovent'],
#  ['Barlaam en Josaphat', 'Floyris ende Blantseflur'],
#  ['Barlaam en Josaphat', 'Fysionomie'],
#  ['Barlaam en Josaphat', 'Gedicht over de hemeltekenen'],
#  ['Barlaam en Josaphat', 'Geraert van Viane'],
#  ['Barlaam en Josaphat', 'Godevaert metten baerde'],
#  ['Barlaam en Josaphat', 'Godevaerts kintshede'],
#  ['Barlaam en Josaphat', 'Grimbergse oorlog'],
#  ['Barlaam en Josaphat', 'Gwidekijn van Sassen'],
#  ['Barlaam en Josaphat', 'Heymelijchede der heymelijcheit'],
#  ['Barlaam en Josaphat', 'Historie van Gaver Capeel'],
#  ['Barlaam en Josaphat', 'Historie van Troyen'],
#  ['Barlaam en Josaphat', 'Huge van Bordeeus'],
#  ['Barlaam en Josaphat', 'Iechemas'],
#  ['Barlaam en Josaphat', 'Jan Splinters testament'],
#  ['Barlaam en Josaphat', 'Jans teesteye'],
#  ['Barlaam en Josaphat', 'Jonathas ende Rosafiere'],
#  ['Barlaam en Josaphat', 'Karel ende Elegast'],
#  ['Barlaam en Josaphat', 'Korte kroniek van Brabant (korte versie 1)'],
#  ['Barlaam en Josaphat', 'Korte kroniek van Brabant (lange versie)'],
#  ['Barlaam en Josaphat', 'Lanceloet en het hert met de witte voet'],
#  ['Barlaam en Josaphat', 'Lancelot'],
#  ['Barlaam en Josaphat', 'Lantsloot van der Haghedochte'],
#  ['Barlaam en Josaphat', 'Lapidarijs'],
#  ['Barlaam en Josaphat', 'Leven van Sint Trudo (berijming)'],
#  ['Barlaam en Josaphat', 'Limborch'],
#  ['Barlaam en Josaphat', 'Limburgse Aiol'],
#  ['Barlaam en Josaphat', 'Lion van Bourges'],
#  ['Barlaam en Josaphat', 'Loyhier en Malaert'],
#  ['Barlaam en Josaphat', 'Madelgijs'],
#  ['Barlaam en Josaphat', 'Melibeus'],
#  ['Barlaam en Josaphat', 'Merlijn'],
#  ['Barlaam en Josaphat', 'Merlijn-continuatie'],
#  ['Barlaam en Josaphat', 'Moriaen'],
#  ['Barlaam en Josaphat', 'Natuurkunde van het geheelal'],
#  ['Barlaam en Josaphat', 'Nevelingenlied'],
#  ['Barlaam en Josaphat', 'Nieuwe doctrinael'],
#  ['Barlaam en Josaphat', 'Noch die tien ghebode'],
#  ['Barlaam en Josaphat', 'Noch meer van wiven'],
#  ['Barlaam en Josaphat', 'Noch van Salladine'],
#  ['Barlaam en Josaphat', 'O crux lignum triumphale'],
#  ['Barlaam en Josaphat', 'Ogier van Denemarken'],
#  ['Barlaam en Josaphat', 'Ongeïdentificeerd (1)'],
#  ['Barlaam en Josaphat', 'Ongeïdentificeerd (2)'],
#  ['Barlaam en Josaphat', 'Ongeïdentificeerd (3)'],
#  ['Barlaam en Josaphat', 'Ongeïdentificeerd (4)'],
#  ['Barlaam en Josaphat', 'Ongeïdentificeerd (6)'],
#  ['Barlaam en Josaphat', 'Ongeïdentificeerd fragment'],
#  ['Barlaam en Josaphat', 'Ons heren passie'],
#  ['Barlaam en Josaphat', 'Parthonopeus van Bloys'],
#  ['Barlaam en Josaphat', 'Perchevael'],
#  ['Barlaam en Josaphat', 'Queeste van den Grale'],
#  ['Barlaam en Josaphat', 'Reinaerts historie'],
#  ['Barlaam en Josaphat', 'Reinout van Montalbaen'],
#  ['Barlaam en Josaphat', 'Renout van Montalbaen'],
#  ['Barlaam en Josaphat', 'Riddere metter mouwen'],
#  ['Barlaam en Josaphat', 'Rijmbijbel'],
#  ['Barlaam en Josaphat', 'Rijmkroniek van Holland'],
#  ['Barlaam en Josaphat', 'Rijmkroniek van Woeringen'],
#  ['Barlaam en Josaphat', 'Roelantslied'],
#  ['Barlaam en Josaphat', 'Roman der Lorreinen I'],
#  ['Barlaam en Josaphat', 'Roman der Lorreinen II'],
#  ['Barlaam en Josaphat', 'Roman van Antiochië'],
#  ['Barlaam en Josaphat', 'Roman van Caesar'],
#  ['Barlaam en Josaphat', 'Roman van Cassamus (kort)'],
#  ['Barlaam en Josaphat', 'Roman van Cassant'],
#  ['Barlaam en Josaphat', 'Rose'],
#  ['Barlaam en Josaphat', 'Rubben'],
#  ['Barlaam en Josaphat', 'Saladin'],
#  ['Barlaam en Josaphat', 'Schepping'],
#  ['Barlaam en Josaphat', 'Segheliin van Jerusalem'],
#  ['Barlaam en Josaphat', 'Sint Patricius'],
#  ['Barlaam en Josaphat', 'Sint Servaes legende'],
#  ['Barlaam en Josaphat', 'Sinte Franciscus leven'],
#  ['Barlaam en Josaphat',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft"],
#  ['Barlaam en Josaphat', 'Sinte Kerstine'],
#  ['Barlaam en Josaphat', 'Sinte Lutgard'],
#  ['Barlaam en Josaphat', 'Slag van Crecy'],
#  ['Barlaam en Josaphat', 'Speghel der wijsheit'],
#  ['Barlaam en Josaphat', 'Spiegel der jongers'],
#  ['Barlaam en Josaphat', 'Spiegel der sonden'],
#  ['Barlaam en Josaphat', 'Spiegel historiael (P1-P4)'],
#  ['Barlaam en Josaphat', 'Spiegel historiael (P2)'],
#  ['Barlaam en Josaphat', 'Spiegel historiael (P4)'],
#  ['Barlaam en Josaphat', 'Spiegel historiael (P5)'],
#  ['Barlaam en Josaphat', 'Spieghel der menscheliker behoudenesse'],
#  ['Barlaam en Josaphat', 'Theophilus'],
#  ['Barlaam en Josaphat', 'Tien plaghen ende die tien ghebode'],
#  ['Barlaam en Josaphat', 'Torec'],
#  ['Barlaam en Josaphat', 'Tristant'],
#  ['Barlaam en Josaphat', 'Valentijn en Nameloos'],
#  ['Barlaam en Josaphat', 'Van Saladijn'],
#  ['Barlaam en Josaphat', 'Van den VII Vroeden van binnen Rome'],
#  ['Barlaam en Josaphat', 'Van den derden Eduwaert'],
#  ['Barlaam en Josaphat', 'Van den neghen besten (kort)'],
#  ['Barlaam en Josaphat', 'Van den neghen besten (lang)'],
#  ['Barlaam en Josaphat', 'Van den vijf vrouden'],
#  ['Barlaam en Josaphat', 'Van den vos Reynaerde'],
#  ['Barlaam en Josaphat', 'Van der manen zeden'],
#  ['Barlaam en Josaphat', 'Van der wive wonderlijcheit (lange versie)'],
#  ['Barlaam en Josaphat', 'Van ghevene'],
#  ['Barlaam en Josaphat', 'Van sente Brandane'],
#  ['Barlaam en Josaphat', 'Van ses vaerwen ende twaelf outheyden'],
#  ['Barlaam en Josaphat', 'Van smeinscen lede'],
#  ['Barlaam en Josaphat', 'Vande Hertogen ende Heeren van Brabant'],
#  ['Barlaam en Josaphat', 'Vanden levene ons heren'],
#  ['Barlaam en Josaphat', 'Vander rijcheit ende vander doot'],
#  ['Barlaam en Josaphat', 'Vlaamse Aiol'],
#  ['Barlaam en Josaphat', 'Vlaamse Rose'],
#  ['Barlaam en Josaphat', 'Walewein (Penninc)'],
#  ['Barlaam en Josaphat', 'Walewein (Vostaert)'],
#  ['Barlaam en Josaphat', 'Walewein ende Keye'],
#  ['Barlaam en Josaphat', 'Willem van Oringen'],
#  ['Barlaam en Josaphat', 'Wisselau'],
#  ['Barlaam en Josaphat', 'Wrake van Ragisel'],
#  ['Beatrijs', 'Bediedenisse van der missen'],
#  ['Beatrijs', 'Beerte metten breden voeten'],
#  ['Beatrijs', 'Beginsel der oorlogen van Luyck'],
#  ['Beatrijs', 'Boec Exemplaer'],
#  ['Beatrijs', 'Boec van den houte'],
#  ['Beatrijs', 'Boec vander wraken'],
#  ['Beatrijs', 'Boeve van Hamtone'],
#  ['Beatrijs', 'Borchgrave van Couchi'],
#  ['Beatrijs', 'Borchgravinne van Vergi (1)'],
#  ['Beatrijs', 'Borchgravinne van Vergi (2)'],
#  ['Beatrijs', 'Boudewijn van Seborch'],
#  ['Beatrijs', 'Brabantsche yeesten (B1-5)'],
#  ['Beatrijs', 'Brabantsche yeesten (B6)'],
#  ['Beatrijs', 'Brabantsche yeesten (B7)'],
#  ['Beatrijs', "Chanson d'Aspremont"],
#  ['Beatrijs', 'Collectief lunarium I'],
#  ['Beatrijs', 'Collectief lunarium II'],
#  ['Beatrijs', 'Collectief lunarium III'],
#  ['Beatrijs', 'Commentaar op het Hooglied'],
#  ['Beatrijs', 'Cyromanchie van den pape van den Hamme'],
#  ['Beatrijs', 'Der leken spieghel'],
#  ['Beatrijs', 'Der mannen ende vrouwen heimelijcheit'],
#  ['Beatrijs', 'Der minnen loep'],
#  ['Beatrijs', 'Der naturen bloeme'],
#  ['Beatrijs', 'Der vrouwen heimelijcheit'],
#  ['Beatrijs', 'Der ystorien bloeme'],
#  ['Beatrijs', 'Dietsche Lucidarius'],
#  ['Beatrijs', 'Dietsche doctrinale'],
#  ['Beatrijs', 'Dystorie van Saladine'],
#  ['Beatrijs', 'Enaamse Codex'],
#  ['Beatrijs', 'Esopet'],
#  ['Beatrijs', 'Expositie vanden viere vingheren ende vanden dume'],
#  ['Beatrijs', 'Ferguut'],
#  ['Beatrijs', 'Fierabras'],
#  ['Beatrijs', 'Flandrijs'],
#  ['Beatrijs', 'Florent ende Durant'],
#  ['Beatrijs', 'Florigout'],
#  ['Beatrijs', 'Florimont'],
#  ['Beatrijs', 'Floris ende Blancefloer'],
#  ['Beatrijs', 'Flovent'],
#  ['Beatrijs', 'Floyris ende Blantseflur'],
#  ['Beatrijs', 'Fysionomie'],
#  ['Beatrijs', 'Gedicht over de hemeltekenen'],
#  ['Beatrijs', 'Geraert van Viane'],
#  ['Beatrijs', 'Godevaert metten baerde'],
#  ['Beatrijs', 'Godevaerts kintshede'],
#  ['Beatrijs', 'Grimbergse oorlog'],
#  ['Beatrijs', 'Gwidekijn van Sassen'],
#  ['Beatrijs', 'Heymelijchede der heymelijcheit'],
#  ['Beatrijs', 'Historie van Gaver Capeel'],
#  ['Beatrijs', 'Historie van Troyen'],
#  ['Beatrijs', 'Huge van Bordeeus'],
#  ['Beatrijs', 'Iechemas'],
#  ['Beatrijs', 'Jan Splinters testament'],
#  ['Beatrijs', 'Jans teesteye'],
#  ...]

# %%
lookup = {}
for t1, t2 in combs:
    try:
        lookup[t1].append(t2)
    except KeyError:
        lookup[t1] = [t2]
lookup
# Out:
# {'Alexanders geesten': ['Alexiuslegende',
#   'Anatomie van de mens',
#   'Arturs doet',
#   'Aubri de Borgengoen',
#   'Barlaam en Josaphat',
#   'Beatrijs',
#   'Bediedenisse van der missen',
#   'Beerte metten breden voeten',
#   'Beginsel der oorlogen van Luyck',
#   'Boec Exemplaer',
#   'Boec van den houte',
#   'Boec vander wraken',
#   'Boeve van Hamtone',
#   'Borchgrave van Couchi',
#   'Borchgravinne van Vergi (1)',
#   'Borchgravinne van Vergi (2)',
#   'Boudewijn van Seborch',
#   'Brabantsche yeesten (B1-5)',
#   'Brabantsche yeesten (B6)',
#   'Brabantsche yeesten (B7)',
#   "Chanson d'Aspremont",
#   'Collectief lunarium I',
#   'Collectief lunarium II',
#   'Collectief lunarium III',
#   'Commentaar op het Hooglied',
#   'Cyromanchie van den pape van den Hamme',
#   'Der leken spieghel',
#   'Der mannen ende vrouwen heimelijcheit',
#   'Der minnen loep',
#   'Der naturen bloeme',
#   'Der vrouwen heimelijcheit',
#   'Der ystorien bloeme',
#   'Dietsche Lucidarius',
#   'Dietsche doctrinale',
#   'Dystorie van Saladine',
#   'Enaamse Codex',
#   'Esopet',
#   'Expositie vanden viere vingheren ende vanden dume',
#   'Ferguut',
#   'Fierabras',
#   'Flandrijs',
#   'Florent ende Durant',
#   'Florigout',
#   'Florimont',
#   'Floris ende Blancefloer',
#   'Flovent',
#   'Floyris ende Blantseflur',
#   'Fysionomie',
#   'Gedicht over de hemeltekenen',
#   'Geraert van Viane',
#   'Godevaert metten baerde',
#   'Godevaerts kintshede',
#   'Grimbergse oorlog',
#   'Gwidekijn van Sassen',
#   'Heymelijchede der heymelijcheit',
#   'Historie van Gaver Capeel',
#   'Historie van Troyen',
#   'Huge van Bordeeus',
#   'Iechemas',
#   'Jan Splinters testament',
#   'Jans teesteye',
#   'Jonathas ende Rosafiere',
#   'Karel ende Elegast',
#   'Korte kroniek van Brabant (korte versie 1)',
#   'Korte kroniek van Brabant (lange versie)',
#   'Lanceloet en het hert met de witte voet',
#   'Lancelot',
#   'Lantsloot van der Haghedochte',
#   'Lapidarijs',
#   'Leven van Sint Trudo (berijming)',
#   'Limborch',
#   'Limburgse Aiol',
#   'Lion van Bourges',
#   'Loyhier en Malaert',
#   'Madelgijs',
#   'Melibeus',
#   'Merlijn',
#   'Merlijn-continuatie',
#   'Moriaen',
#   'Natuurkunde van het geheelal',
#   'Nevelingenlied',
#   'Nieuwe doctrinael',
#   'Noch die tien ghebode',
#   'Noch meer van wiven',
#   'Noch van Salladine',
#   'O crux lignum triumphale',
#   'Ogier van Denemarken',
#   'Ongeïdentificeerd (1)',
#   'Ongeïdentificeerd (2)',
#   'Ongeïdentificeerd (3)',
#   'Ongeïdentificeerd (4)',
#   'Ongeïdentificeerd (6)',
#   'Ongeïdentificeerd fragment',
#   'Ons heren passie',
#   'Parthonopeus van Bloys',
#   'Perchevael',
#   'Queeste van den Grale',
#   'Reinaerts historie',
#   'Reinout van Montalbaen',
#   'Renout van Montalbaen',
#   'Riddere metter mouwen',
#   'Rijmbijbel',
#   'Rijmkroniek van Holland',
#   'Rijmkroniek van Woeringen',
#   'Roelantslied',
#   'Roman der Lorreinen I',
#   'Roman der Lorreinen II',
#   'Roman van Antiochië',
#   'Roman van Caesar',
#   'Roman van Cassamus (kort)',
#   'Roman van Cassant',
#   'Rose',
#   'Rubben',
#   'Saladin',
#   'Schepping',
#   'Segheliin van Jerusalem',
#   'Sint Patricius',
#   'Sint Servaes legende',
#   'Sinte Franciscus leven',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft",
#   'Sinte Kerstine',
#   'Sinte Lutgard',
#   'Slag van Crecy',
#   'Speghel der wijsheit',
#   'Spiegel der jongers',
#   'Spiegel der sonden',
#   'Spiegel historiael (P1-P4)',
#   'Spiegel historiael (P2)',
#   'Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Alexiuslegende': ['Anatomie van de mens',
#   'Arturs doet',
#   'Aubri de Borgengoen',
#   'Barlaam en Josaphat',
#   'Beatrijs',
#   'Bediedenisse van der missen',
#   'Beerte metten breden voeten',
#   'Beginsel der oorlogen van Luyck',
#   'Boec Exemplaer',
#   'Boec van den houte',
#   'Boec vander wraken',
#   'Boeve van Hamtone',
#   'Borchgrave van Couchi',
#   'Borchgravinne van Vergi (1)',
#   'Borchgravinne van Vergi (2)',
#   'Boudewijn van Seborch',
#   'Brabantsche yeesten (B1-5)',
#   'Brabantsche yeesten (B6)',
#   'Brabantsche yeesten (B7)',
#   "Chanson d'Aspremont",
#   'Collectief lunarium I',
#   'Collectief lunarium II',
#   'Collectief lunarium III',
#   'Commentaar op het Hooglied',
#   'Cyromanchie van den pape van den Hamme',
#   'Der leken spieghel',
#   'Der mannen ende vrouwen heimelijcheit',
#   'Der minnen loep',
#   'Der naturen bloeme',
#   'Der vrouwen heimelijcheit',
#   'Der ystorien bloeme',
#   'Dietsche Lucidarius',
#   'Dietsche doctrinale',
#   'Dystorie van Saladine',
#   'Enaamse Codex',
#   'Esopet',
#   'Expositie vanden viere vingheren ende vanden dume',
#   'Ferguut',
#   'Fierabras',
#   'Flandrijs',
#   'Florent ende Durant',
#   'Florigout',
#   'Florimont',
#   'Floris ende Blancefloer',
#   'Flovent',
#   'Floyris ende Blantseflur',
#   'Fysionomie',
#   'Gedicht over de hemeltekenen',
#   'Geraert van Viane',
#   'Godevaert metten baerde',
#   'Godevaerts kintshede',
#   'Grimbergse oorlog',
#   'Gwidekijn van Sassen',
#   'Heymelijchede der heymelijcheit',
#   'Historie van Gaver Capeel',
#   'Historie van Troyen',
#   'Huge van Bordeeus',
#   'Iechemas',
#   'Jan Splinters testament',
#   'Jans teesteye',
#   'Jonathas ende Rosafiere',
#   'Karel ende Elegast',
#   'Korte kroniek van Brabant (korte versie 1)',
#   'Korte kroniek van Brabant (lange versie)',
#   'Lanceloet en het hert met de witte voet',
#   'Lancelot',
#   'Lantsloot van der Haghedochte',
#   'Lapidarijs',
#   'Leven van Sint Trudo (berijming)',
#   'Limborch',
#   'Limburgse Aiol',
#   'Lion van Bourges',
#   'Loyhier en Malaert',
#   'Madelgijs',
#   'Melibeus',
#   'Merlijn',
#   'Merlijn-continuatie',
#   'Moriaen',
#   'Natuurkunde van het geheelal',
#   'Nevelingenlied',
#   'Nieuwe doctrinael',
#   'Noch die tien ghebode',
#   'Noch meer van wiven',
#   'Noch van Salladine',
#   'O crux lignum triumphale',
#   'Ogier van Denemarken',
#   'Ongeïdentificeerd (1)',
#   'Ongeïdentificeerd (2)',
#   'Ongeïdentificeerd (3)',
#   'Ongeïdentificeerd (4)',
#   'Ongeïdentificeerd (6)',
#   'Ongeïdentificeerd fragment',
#   'Ons heren passie',
#   'Parthonopeus van Bloys',
#   'Perchevael',
#   'Queeste van den Grale',
#   'Reinaerts historie',
#   'Reinout van Montalbaen',
#   'Renout van Montalbaen',
#   'Riddere metter mouwen',
#   'Rijmbijbel',
#   'Rijmkroniek van Holland',
#   'Rijmkroniek van Woeringen',
#   'Roelantslied',
#   'Roman der Lorreinen I',
#   'Roman der Lorreinen II',
#   'Roman van Antiochië',
#   'Roman van Caesar',
#   'Roman van Cassamus (kort)',
#   'Roman van Cassant',
#   'Rose',
#   'Rubben',
#   'Saladin',
#   'Schepping',
#   'Segheliin van Jerusalem',
#   'Sint Patricius',
#   'Sint Servaes legende',
#   'Sinte Franciscus leven',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft",
#   'Sinte Kerstine',
#   'Sinte Lutgard',
#   'Slag van Crecy',
#   'Speghel der wijsheit',
#   'Spiegel der jongers',
#   'Spiegel der sonden',
#   'Spiegel historiael (P1-P4)',
#   'Spiegel historiael (P2)',
#   'Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Anatomie van de mens': ['Arturs doet',
#   'Aubri de Borgengoen',
#   'Barlaam en Josaphat',
#   'Beatrijs',
#   'Bediedenisse van der missen',
#   'Beerte metten breden voeten',
#   'Beginsel der oorlogen van Luyck',
#   'Boec Exemplaer',
#   'Boec van den houte',
#   'Boec vander wraken',
#   'Boeve van Hamtone',
#   'Borchgrave van Couchi',
#   'Borchgravinne van Vergi (1)',
#   'Borchgravinne van Vergi (2)',
#   'Boudewijn van Seborch',
#   'Brabantsche yeesten (B1-5)',
#   'Brabantsche yeesten (B6)',
#   'Brabantsche yeesten (B7)',
#   "Chanson d'Aspremont",
#   'Collectief lunarium I',
#   'Collectief lunarium II',
#   'Collectief lunarium III',
#   'Commentaar op het Hooglied',
#   'Cyromanchie van den pape van den Hamme',
#   'Der leken spieghel',
#   'Der mannen ende vrouwen heimelijcheit',
#   'Der minnen loep',
#   'Der naturen bloeme',
#   'Der vrouwen heimelijcheit',
#   'Der ystorien bloeme',
#   'Dietsche Lucidarius',
#   'Dietsche doctrinale',
#   'Dystorie van Saladine',
#   'Enaamse Codex',
#   'Esopet',
#   'Expositie vanden viere vingheren ende vanden dume',
#   'Ferguut',
#   'Fierabras',
#   'Flandrijs',
#   'Florent ende Durant',
#   'Florigout',
#   'Florimont',
#   'Floris ende Blancefloer',
#   'Flovent',
#   'Floyris ende Blantseflur',
#   'Fysionomie',
#   'Gedicht over de hemeltekenen',
#   'Geraert van Viane',
#   'Godevaert metten baerde',
#   'Godevaerts kintshede',
#   'Grimbergse oorlog',
#   'Gwidekijn van Sassen',
#   'Heymelijchede der heymelijcheit',
#   'Historie van Gaver Capeel',
#   'Historie van Troyen',
#   'Huge van Bordeeus',
#   'Iechemas',
#   'Jan Splinters testament',
#   'Jans teesteye',
#   'Jonathas ende Rosafiere',
#   'Karel ende Elegast',
#   'Korte kroniek van Brabant (korte versie 1)',
#   'Korte kroniek van Brabant (lange versie)',
#   'Lanceloet en het hert met de witte voet',
#   'Lancelot',
#   'Lantsloot van der Haghedochte',
#   'Lapidarijs',
#   'Leven van Sint Trudo (berijming)',
#   'Limborch',
#   'Limburgse Aiol',
#   'Lion van Bourges',
#   'Loyhier en Malaert',
#   'Madelgijs',
#   'Melibeus',
#   'Merlijn',
#   'Merlijn-continuatie',
#   'Moriaen',
#   'Natuurkunde van het geheelal',
#   'Nevelingenlied',
#   'Nieuwe doctrinael',
#   'Noch die tien ghebode',
#   'Noch meer van wiven',
#   'Noch van Salladine',
#   'O crux lignum triumphale',
#   'Ogier van Denemarken',
#   'Ongeïdentificeerd (1)',
#   'Ongeïdentificeerd (2)',
#   'Ongeïdentificeerd (3)',
#   'Ongeïdentificeerd (4)',
#   'Ongeïdentificeerd (6)',
#   'Ongeïdentificeerd fragment',
#   'Ons heren passie',
#   'Parthonopeus van Bloys',
#   'Perchevael',
#   'Queeste van den Grale',
#   'Reinaerts historie',
#   'Reinout van Montalbaen',
#   'Renout van Montalbaen',
#   'Riddere metter mouwen',
#   'Rijmbijbel',
#   'Rijmkroniek van Holland',
#   'Rijmkroniek van Woeringen',
#   'Roelantslied',
#   'Roman der Lorreinen I',
#   'Roman der Lorreinen II',
#   'Roman van Antiochië',
#   'Roman van Caesar',
#   'Roman van Cassamus (kort)',
#   'Roman van Cassant',
#   'Rose',
#   'Rubben',
#   'Saladin',
#   'Schepping',
#   'Segheliin van Jerusalem',
#   'Sint Patricius',
#   'Sint Servaes legende',
#   'Sinte Franciscus leven',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft",
#   'Sinte Kerstine',
#   'Sinte Lutgard',
#   'Slag van Crecy',
#   'Speghel der wijsheit',
#   'Spiegel der jongers',
#   'Spiegel der sonden',
#   'Spiegel historiael (P1-P4)',
#   'Spiegel historiael (P2)',
#   'Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Arturs doet': ['Aubri de Borgengoen',
#   'Barlaam en Josaphat',
#   'Beatrijs',
#   'Bediedenisse van der missen',
#   'Beerte metten breden voeten',
#   'Beginsel der oorlogen van Luyck',
#   'Boec Exemplaer',
#   'Boec van den houte',
#   'Boec vander wraken',
#   'Boeve van Hamtone',
#   'Borchgrave van Couchi',
#   'Borchgravinne van Vergi (1)',
#   'Borchgravinne van Vergi (2)',
#   'Boudewijn van Seborch',
#   'Brabantsche yeesten (B1-5)',
#   'Brabantsche yeesten (B6)',
#   'Brabantsche yeesten (B7)',
#   "Chanson d'Aspremont",
#   'Collectief lunarium I',
#   'Collectief lunarium II',
#   'Collectief lunarium III',
#   'Commentaar op het Hooglied',
#   'Cyromanchie van den pape van den Hamme',
#   'Der leken spieghel',
#   'Der mannen ende vrouwen heimelijcheit',
#   'Der minnen loep',
#   'Der naturen bloeme',
#   'Der vrouwen heimelijcheit',
#   'Der ystorien bloeme',
#   'Dietsche Lucidarius',
#   'Dietsche doctrinale',
#   'Dystorie van Saladine',
#   'Enaamse Codex',
#   'Esopet',
#   'Expositie vanden viere vingheren ende vanden dume',
#   'Ferguut',
#   'Fierabras',
#   'Flandrijs',
#   'Florent ende Durant',
#   'Florigout',
#   'Florimont',
#   'Floris ende Blancefloer',
#   'Flovent',
#   'Floyris ende Blantseflur',
#   'Fysionomie',
#   'Gedicht over de hemeltekenen',
#   'Geraert van Viane',
#   'Godevaert metten baerde',
#   'Godevaerts kintshede',
#   'Grimbergse oorlog',
#   'Gwidekijn van Sassen',
#   'Heymelijchede der heymelijcheit',
#   'Historie van Gaver Capeel',
#   'Historie van Troyen',
#   'Huge van Bordeeus',
#   'Iechemas',
#   'Jan Splinters testament',
#   'Jans teesteye',
#   'Jonathas ende Rosafiere',
#   'Karel ende Elegast',
#   'Korte kroniek van Brabant (korte versie 1)',
#   'Korte kroniek van Brabant (lange versie)',
#   'Lanceloet en het hert met de witte voet',
#   'Lancelot',
#   'Lantsloot van der Haghedochte',
#   'Lapidarijs',
#   'Leven van Sint Trudo (berijming)',
#   'Limborch',
#   'Limburgse Aiol',
#   'Lion van Bourges',
#   'Loyhier en Malaert',
#   'Madelgijs',
#   'Melibeus',
#   'Merlijn',
#   'Merlijn-continuatie',
#   'Moriaen',
#   'Natuurkunde van het geheelal',
#   'Nevelingenlied',
#   'Nieuwe doctrinael',
#   'Noch die tien ghebode',
#   'Noch meer van wiven',
#   'Noch van Salladine',
#   'O crux lignum triumphale',
#   'Ogier van Denemarken',
#   'Ongeïdentificeerd (1)',
#   'Ongeïdentificeerd (2)',
#   'Ongeïdentificeerd (3)',
#   'Ongeïdentificeerd (4)',
#   'Ongeïdentificeerd (6)',
#   'Ongeïdentificeerd fragment',
#   'Ons heren passie',
#   'Parthonopeus van Bloys',
#   'Perchevael',
#   'Queeste van den Grale',
#   'Reinaerts historie',
#   'Reinout van Montalbaen',
#   'Renout van Montalbaen',
#   'Riddere metter mouwen',
#   'Rijmbijbel',
#   'Rijmkroniek van Holland',
#   'Rijmkroniek van Woeringen',
#   'Roelantslied',
#   'Roman der Lorreinen I',
#   'Roman der Lorreinen II',
#   'Roman van Antiochië',
#   'Roman van Caesar',
#   'Roman van Cassamus (kort)',
#   'Roman van Cassant',
#   'Rose',
#   'Rubben',
#   'Saladin',
#   'Schepping',
#   'Segheliin van Jerusalem',
#   'Sint Patricius',
#   'Sint Servaes legende',
#   'Sinte Franciscus leven',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft",
#   'Sinte Kerstine',
#   'Sinte Lutgard',
#   'Slag van Crecy',
#   'Speghel der wijsheit',
#   'Spiegel der jongers',
#   'Spiegel der sonden',
#   'Spiegel historiael (P1-P4)',
#   'Spiegel historiael (P2)',
#   'Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Aubri de Borgengoen': ['Barlaam en Josaphat',
#   'Beatrijs',
#   'Bediedenisse van der missen',
#   'Beerte metten breden voeten',
#   'Beginsel der oorlogen van Luyck',
#   'Boec Exemplaer',
#   'Boec van den houte',
#   'Boec vander wraken',
#   'Boeve van Hamtone',
#   'Borchgrave van Couchi',
#   'Borchgravinne van Vergi (1)',
#   'Borchgravinne van Vergi (2)',
#   'Boudewijn van Seborch',
#   'Brabantsche yeesten (B1-5)',
#   'Brabantsche yeesten (B6)',
#   'Brabantsche yeesten (B7)',
#   "Chanson d'Aspremont",
#   'Collectief lunarium I',
#   'Collectief lunarium II',
#   'Collectief lunarium III',
#   'Commentaar op het Hooglied',
#   'Cyromanchie van den pape van den Hamme',
#   'Der leken spieghel',
#   'Der mannen ende vrouwen heimelijcheit',
#   'Der minnen loep',
#   'Der naturen bloeme',
#   'Der vrouwen heimelijcheit',
#   'Der ystorien bloeme',
#   'Dietsche Lucidarius',
#   'Dietsche doctrinale',
#   'Dystorie van Saladine',
#   'Enaamse Codex',
#   'Esopet',
#   'Expositie vanden viere vingheren ende vanden dume',
#   'Ferguut',
#   'Fierabras',
#   'Flandrijs',
#   'Florent ende Durant',
#   'Florigout',
#   'Florimont',
#   'Floris ende Blancefloer',
#   'Flovent',
#   'Floyris ende Blantseflur',
#   'Fysionomie',
#   'Gedicht over de hemeltekenen',
#   'Geraert van Viane',
#   'Godevaert metten baerde',
#   'Godevaerts kintshede',
#   'Grimbergse oorlog',
#   'Gwidekijn van Sassen',
#   'Heymelijchede der heymelijcheit',
#   'Historie van Gaver Capeel',
#   'Historie van Troyen',
#   'Huge van Bordeeus',
#   'Iechemas',
#   'Jan Splinters testament',
#   'Jans teesteye',
#   'Jonathas ende Rosafiere',
#   'Karel ende Elegast',
#   'Korte kroniek van Brabant (korte versie 1)',
#   'Korte kroniek van Brabant (lange versie)',
#   'Lanceloet en het hert met de witte voet',
#   'Lancelot',
#   'Lantsloot van der Haghedochte',
#   'Lapidarijs',
#   'Leven van Sint Trudo (berijming)',
#   'Limborch',
#   'Limburgse Aiol',
#   'Lion van Bourges',
#   'Loyhier en Malaert',
#   'Madelgijs',
#   'Melibeus',
#   'Merlijn',
#   'Merlijn-continuatie',
#   'Moriaen',
#   'Natuurkunde van het geheelal',
#   'Nevelingenlied',
#   'Nieuwe doctrinael',
#   'Noch die tien ghebode',
#   'Noch meer van wiven',
#   'Noch van Salladine',
#   'O crux lignum triumphale',
#   'Ogier van Denemarken',
#   'Ongeïdentificeerd (1)',
#   'Ongeïdentificeerd (2)',
#   'Ongeïdentificeerd (3)',
#   'Ongeïdentificeerd (4)',
#   'Ongeïdentificeerd (6)',
#   'Ongeïdentificeerd fragment',
#   'Ons heren passie',
#   'Parthonopeus van Bloys',
#   'Perchevael',
#   'Queeste van den Grale',
#   'Reinaerts historie',
#   'Reinout van Montalbaen',
#   'Renout van Montalbaen',
#   'Riddere metter mouwen',
#   'Rijmbijbel',
#   'Rijmkroniek van Holland',
#   'Rijmkroniek van Woeringen',
#   'Roelantslied',
#   'Roman der Lorreinen I',
#   'Roman der Lorreinen II',
#   'Roman van Antiochië',
#   'Roman van Caesar',
#   'Roman van Cassamus (kort)',
#   'Roman van Cassant',
#   'Rose',
#   'Rubben',
#   'Saladin',
#   'Schepping',
#   'Segheliin van Jerusalem',
#   'Sint Patricius',
#   'Sint Servaes legende',
#   'Sinte Franciscus leven',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft",
#   'Sinte Kerstine',
#   'Sinte Lutgard',
#   'Slag van Crecy',
#   'Speghel der wijsheit',
#   'Spiegel der jongers',
#   'Spiegel der sonden',
#   'Spiegel historiael (P1-P4)',
#   'Spiegel historiael (P2)',
#   'Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Barlaam en Josaphat': ['Beatrijs',
#   'Bediedenisse van der missen',
#   'Beerte metten breden voeten',
#   'Beginsel der oorlogen van Luyck',
#   'Boec Exemplaer',
#   'Boec van den houte',
#   'Boec vander wraken',
#   'Boeve van Hamtone',
#   'Borchgrave van Couchi',
#   'Borchgravinne van Vergi (1)',
#   'Borchgravinne van Vergi (2)',
#   'Boudewijn van Seborch',
#   'Brabantsche yeesten (B1-5)',
#   'Brabantsche yeesten (B6)',
#   'Brabantsche yeesten (B7)',
#   "Chanson d'Aspremont",
#   'Collectief lunarium I',
#   'Collectief lunarium II',
#   'Collectief lunarium III',
#   'Commentaar op het Hooglied',
#   'Cyromanchie van den pape van den Hamme',
#   'Der leken spieghel',
#   'Der mannen ende vrouwen heimelijcheit',
#   'Der minnen loep',
#   'Der naturen bloeme',
#   'Der vrouwen heimelijcheit',
#   'Der ystorien bloeme',
#   'Dietsche Lucidarius',
#   'Dietsche doctrinale',
#   'Dystorie van Saladine',
#   'Enaamse Codex',
#   'Esopet',
#   'Expositie vanden viere vingheren ende vanden dume',
#   'Ferguut',
#   'Fierabras',
#   'Flandrijs',
#   'Florent ende Durant',
#   'Florigout',
#   'Florimont',
#   'Floris ende Blancefloer',
#   'Flovent',
#   'Floyris ende Blantseflur',
#   'Fysionomie',
#   'Gedicht over de hemeltekenen',
#   'Geraert van Viane',
#   'Godevaert metten baerde',
#   'Godevaerts kintshede',
#   'Grimbergse oorlog',
#   'Gwidekijn van Sassen',
#   'Heymelijchede der heymelijcheit',
#   'Historie van Gaver Capeel',
#   'Historie van Troyen',
#   'Huge van Bordeeus',
#   'Iechemas',
#   'Jan Splinters testament',
#   'Jans teesteye',
#   'Jonathas ende Rosafiere',
#   'Karel ende Elegast',
#   'Korte kroniek van Brabant (korte versie 1)',
#   'Korte kroniek van Brabant (lange versie)',
#   'Lanceloet en het hert met de witte voet',
#   'Lancelot',
#   'Lantsloot van der Haghedochte',
#   'Lapidarijs',
#   'Leven van Sint Trudo (berijming)',
#   'Limborch',
#   'Limburgse Aiol',
#   'Lion van Bourges',
#   'Loyhier en Malaert',
#   'Madelgijs',
#   'Melibeus',
#   'Merlijn',
#   'Merlijn-continuatie',
#   'Moriaen',
#   'Natuurkunde van het geheelal',
#   'Nevelingenlied',
#   'Nieuwe doctrinael',
#   'Noch die tien ghebode',
#   'Noch meer van wiven',
#   'Noch van Salladine',
#   'O crux lignum triumphale',
#   'Ogier van Denemarken',
#   'Ongeïdentificeerd (1)',
#   'Ongeïdentificeerd (2)',
#   'Ongeïdentificeerd (3)',
#   'Ongeïdentificeerd (4)',
#   'Ongeïdentificeerd (6)',
#   'Ongeïdentificeerd fragment',
#   'Ons heren passie',
#   'Parthonopeus van Bloys',
#   'Perchevael',
#   'Queeste van den Grale',
#   'Reinaerts historie',
#   'Reinout van Montalbaen',
#   'Renout van Montalbaen',
#   'Riddere metter mouwen',
#   'Rijmbijbel',
#   'Rijmkroniek van Holland',
#   'Rijmkroniek van Woeringen',
#   'Roelantslied',
#   'Roman der Lorreinen I',
#   'Roman der Lorreinen II',
#   'Roman van Antiochië',
#   'Roman van Caesar',
#   'Roman van Cassamus (kort)',
#   'Roman van Cassant',
#   'Rose',
#   'Rubben',
#   'Saladin',
#   'Schepping',
#   'Segheliin van Jerusalem',
#   'Sint Patricius',
#   'Sint Servaes legende',
#   'Sinte Franciscus leven',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft",
#   'Sinte Kerstine',
#   'Sinte Lutgard',
#   'Slag van Crecy',
#   'Speghel der wijsheit',
#   'Spiegel der jongers',
#   'Spiegel der sonden',
#   'Spiegel historiael (P1-P4)',
#   'Spiegel historiael (P2)',
#   'Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Beatrijs': ['Bediedenisse van der missen',
#   'Beerte metten breden voeten',
#   'Beginsel der oorlogen van Luyck',
#   'Boec Exemplaer',
#   'Boec van den houte',
#   'Boec vander wraken',
#   'Boeve van Hamtone',
#   'Borchgrave van Couchi',
#   'Borchgravinne van Vergi (1)',
#   'Borchgravinne van Vergi (2)',
#   'Boudewijn van Seborch',
#   'Brabantsche yeesten (B1-5)',
#   'Brabantsche yeesten (B6)',
#   'Brabantsche yeesten (B7)',
#   "Chanson d'Aspremont",
#   'Collectief lunarium I',
#   'Collectief lunarium II',
#   'Collectief lunarium III',
#   'Commentaar op het Hooglied',
#   'Cyromanchie van den pape van den Hamme',
#   'Der leken spieghel',
#   'Der mannen ende vrouwen heimelijcheit',
#   'Der minnen loep',
#   'Der naturen bloeme',
#   'Der vrouwen heimelijcheit',
#   'Der ystorien bloeme',
#   'Dietsche Lucidarius',
#   'Dietsche doctrinale',
#   'Dystorie van Saladine',
#   'Enaamse Codex',
#   'Esopet',
#   'Expositie vanden viere vingheren ende vanden dume',
#   'Ferguut',
#   'Fierabras',
#   'Flandrijs',
#   'Florent ende Durant',
#   'Florigout',
#   'Florimont',
#   'Floris ende Blancefloer',
#   'Flovent',
#   'Floyris ende Blantseflur',
#   'Fysionomie',
#   'Gedicht over de hemeltekenen',
#   'Geraert van Viane',
#   'Godevaert metten baerde',
#   'Godevaerts kintshede',
#   'Grimbergse oorlog',
#   'Gwidekijn van Sassen',
#   'Heymelijchede der heymelijcheit',
#   'Historie van Gaver Capeel',
#   'Historie van Troyen',
#   'Huge van Bordeeus',
#   'Iechemas',
#   'Jan Splinters testament',
#   'Jans teesteye',
#   'Jonathas ende Rosafiere',
#   'Karel ende Elegast',
#   'Korte kroniek van Brabant (korte versie 1)',
#   'Korte kroniek van Brabant (lange versie)',
#   'Lanceloet en het hert met de witte voet',
#   'Lancelot',
#   'Lantsloot van der Haghedochte',
#   'Lapidarijs',
#   'Leven van Sint Trudo (berijming)',
#   'Limborch',
#   'Limburgse Aiol',
#   'Lion van Bourges',
#   'Loyhier en Malaert',
#   'Madelgijs',
#   'Melibeus',
#   'Merlijn',
#   'Merlijn-continuatie',
#   'Moriaen',
#   'Natuurkunde van het geheelal',
#   'Nevelingenlied',
#   'Nieuwe doctrinael',
#   'Noch die tien ghebode',
#   'Noch meer van wiven',
#   'Noch van Salladine',
#   'O crux lignum triumphale',
#   'Ogier van Denemarken',
#   'Ongeïdentificeerd (1)',
#   'Ongeïdentificeerd (2)',
#   'Ongeïdentificeerd (3)',
#   'Ongeïdentificeerd (4)',
#   'Ongeïdentificeerd (6)',
#   'Ongeïdentificeerd fragment',
#   'Ons heren passie',
#   'Parthonopeus van Bloys',
#   'Perchevael',
#   'Queeste van den Grale',
#   'Reinaerts historie',
#   'Reinout van Montalbaen',
#   'Renout van Montalbaen',
#   'Riddere metter mouwen',
#   'Rijmbijbel',
#   'Rijmkroniek van Holland',
#   'Rijmkroniek van Woeringen',
#   'Roelantslied',
#   'Roman der Lorreinen I',
#   'Roman der Lorreinen II',
#   'Roman van Antiochië',
#   'Roman van Caesar',
#   'Roman van Cassamus (kort)',
#   'Roman van Cassant',
#   'Rose',
#   'Rubben',
#   'Saladin',
#   'Schepping',
#   'Segheliin van Jerusalem',
#   'Sint Patricius',
#   'Sint Servaes legende',
#   'Sinte Franciscus leven',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft",
#   'Sinte Kerstine',
#   'Sinte Lutgard',
#   'Slag van Crecy',
#   'Speghel der wijsheit',
#   'Spiegel der jongers',
#   'Spiegel der sonden',
#   'Spiegel historiael (P1-P4)',
#   'Spiegel historiael (P2)',
#   'Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Bediedenisse van der missen': ['Beerte metten breden voeten',
#   'Beginsel der oorlogen van Luyck',
#   'Boec Exemplaer',
#   'Boec van den houte',
#   'Boec vander wraken',
#   'Boeve van Hamtone',
#   'Borchgrave van Couchi',
#   'Borchgravinne van Vergi (1)',
#   'Borchgravinne van Vergi (2)',
#   'Boudewijn van Seborch',
#   'Brabantsche yeesten (B1-5)',
#   'Brabantsche yeesten (B6)',
#   'Brabantsche yeesten (B7)',
#   "Chanson d'Aspremont",
#   'Collectief lunarium I',
#   'Collectief lunarium II',
#   'Collectief lunarium III',
#   'Commentaar op het Hooglied',
#   'Cyromanchie van den pape van den Hamme',
#   'Der leken spieghel',
#   'Der mannen ende vrouwen heimelijcheit',
#   'Der minnen loep',
#   'Der naturen bloeme',
#   'Der vrouwen heimelijcheit',
#   'Der ystorien bloeme',
#   'Dietsche Lucidarius',
#   'Dietsche doctrinale',
#   'Dystorie van Saladine',
#   'Enaamse Codex',
#   'Esopet',
#   'Expositie vanden viere vingheren ende vanden dume',
#   'Ferguut',
#   'Fierabras',
#   'Flandrijs',
#   'Florent ende Durant',
#   'Florigout',
#   'Florimont',
#   'Floris ende Blancefloer',
#   'Flovent',
#   'Floyris ende Blantseflur',
#   'Fysionomie',
#   'Gedicht over de hemeltekenen',
#   'Geraert van Viane',
#   'Godevaert metten baerde',
#   'Godevaerts kintshede',
#   'Grimbergse oorlog',
#   'Gwidekijn van Sassen',
#   'Heymelijchede der heymelijcheit',
#   'Historie van Gaver Capeel',
#   'Historie van Troyen',
#   'Huge van Bordeeus',
#   'Iechemas',
#   'Jan Splinters testament',
#   'Jans teesteye',
#   'Jonathas ende Rosafiere',
#   'Karel ende Elegast',
#   'Korte kroniek van Brabant (korte versie 1)',
#   'Korte kroniek van Brabant (lange versie)',
#   'Lanceloet en het hert met de witte voet',
#   'Lancelot',
#   'Lantsloot van der Haghedochte',
#   'Lapidarijs',
#   'Leven van Sint Trudo (berijming)',
#   'Limborch',
#   'Limburgse Aiol',
#   'Lion van Bourges',
#   'Loyhier en Malaert',
#   'Madelgijs',
#   'Melibeus',
#   'Merlijn',
#   'Merlijn-continuatie',
#   'Moriaen',
#   'Natuurkunde van het geheelal',
#   'Nevelingenlied',
#   'Nieuwe doctrinael',
#   'Noch die tien ghebode',
#   'Noch meer van wiven',
#   'Noch van Salladine',
#   'O crux lignum triumphale',
#   'Ogier van Denemarken',
#   'Ongeïdentificeerd (1)',
#   'Ongeïdentificeerd (2)',
#   'Ongeïdentificeerd (3)',
#   'Ongeïdentificeerd (4)',
#   'Ongeïdentificeerd (6)',
#   'Ongeïdentificeerd fragment',
#   'Ons heren passie',
#   'Parthonopeus van Bloys',
#   'Perchevael',
#   'Queeste van den Grale',
#   'Reinaerts historie',
#   'Reinout van Montalbaen',
#   'Renout van Montalbaen',
#   'Riddere metter mouwen',
#   'Rijmbijbel',
#   'Rijmkroniek van Holland',
#   'Rijmkroniek van Woeringen',
#   'Roelantslied',
#   'Roman der Lorreinen I',
#   'Roman der Lorreinen II',
#   'Roman van Antiochië',
#   'Roman van Caesar',
#   'Roman van Cassamus (kort)',
#   'Roman van Cassant',
#   'Rose',
#   'Rubben',
#   'Saladin',
#   'Schepping',
#   'Segheliin van Jerusalem',
#   'Sint Patricius',
#   'Sint Servaes legende',
#   'Sinte Franciscus leven',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft",
#   'Sinte Kerstine',
#   'Sinte Lutgard',
#   'Slag van Crecy',
#   'Speghel der wijsheit',
#   'Spiegel der jongers',
#   'Spiegel der sonden',
#   'Spiegel historiael (P1-P4)',
#   'Spiegel historiael (P2)',
#   'Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Beerte metten breden voeten': ['Beginsel der oorlogen van Luyck',
#   'Boec Exemplaer',
#   'Boec van den houte',
#   'Boec vander wraken',
#   'Boeve van Hamtone',
#   'Borchgrave van Couchi',
#   'Borchgravinne van Vergi (1)',
#   'Borchgravinne van Vergi (2)',
#   'Boudewijn van Seborch',
#   'Brabantsche yeesten (B1-5)',
#   'Brabantsche yeesten (B6)',
#   'Brabantsche yeesten (B7)',
#   "Chanson d'Aspremont",
#   'Collectief lunarium I',
#   'Collectief lunarium II',
#   'Collectief lunarium III',
#   'Commentaar op het Hooglied',
#   'Cyromanchie van den pape van den Hamme',
#   'Der leken spieghel',
#   'Der mannen ende vrouwen heimelijcheit',
#   'Der minnen loep',
#   'Der naturen bloeme',
#   'Der vrouwen heimelijcheit',
#   'Der ystorien bloeme',
#   'Dietsche Lucidarius',
#   'Dietsche doctrinale',
#   'Dystorie van Saladine',
#   'Enaamse Codex',
#   'Esopet',
#   'Expositie vanden viere vingheren ende vanden dume',
#   'Ferguut',
#   'Fierabras',
#   'Flandrijs',
#   'Florent ende Durant',
#   'Florigout',
#   'Florimont',
#   'Floris ende Blancefloer',
#   'Flovent',
#   'Floyris ende Blantseflur',
#   'Fysionomie',
#   'Gedicht over de hemeltekenen',
#   'Geraert van Viane',
#   'Godevaert metten baerde',
#   'Godevaerts kintshede',
#   'Grimbergse oorlog',
#   'Gwidekijn van Sassen',
#   'Heymelijchede der heymelijcheit',
#   'Historie van Gaver Capeel',
#   'Historie van Troyen',
#   'Huge van Bordeeus',
#   'Iechemas',
#   'Jan Splinters testament',
#   'Jans teesteye',
#   'Jonathas ende Rosafiere',
#   'Karel ende Elegast',
#   'Korte kroniek van Brabant (korte versie 1)',
#   'Korte kroniek van Brabant (lange versie)',
#   'Lanceloet en het hert met de witte voet',
#   'Lancelot',
#   'Lantsloot van der Haghedochte',
#   'Lapidarijs',
#   'Leven van Sint Trudo (berijming)',
#   'Limborch',
#   'Limburgse Aiol',
#   'Lion van Bourges',
#   'Loyhier en Malaert',
#   'Madelgijs',
#   'Melibeus',
#   'Merlijn',
#   'Merlijn-continuatie',
#   'Moriaen',
#   'Natuurkunde van het geheelal',
#   'Nevelingenlied',
#   'Nieuwe doctrinael',
#   'Noch die tien ghebode',
#   'Noch meer van wiven',
#   'Noch van Salladine',
#   'O crux lignum triumphale',
#   'Ogier van Denemarken',
#   'Ongeïdentificeerd (1)',
#   'Ongeïdentificeerd (2)',
#   'Ongeïdentificeerd (3)',
#   'Ongeïdentificeerd (4)',
#   'Ongeïdentificeerd (6)',
#   'Ongeïdentificeerd fragment',
#   'Ons heren passie',
#   'Parthonopeus van Bloys',
#   'Perchevael',
#   'Queeste van den Grale',
#   'Reinaerts historie',
#   'Reinout van Montalbaen',
#   'Renout van Montalbaen',
#   'Riddere metter mouwen',
#   'Rijmbijbel',
#   'Rijmkroniek van Holland',
#   'Rijmkroniek van Woeringen',
#   'Roelantslied',
#   'Roman der Lorreinen I',
#   'Roman der Lorreinen II',
#   'Roman van Antiochië',
#   'Roman van Caesar',
#   'Roman van Cassamus (kort)',
#   'Roman van Cassant',
#   'Rose',
#   'Rubben',
#   'Saladin',
#   'Schepping',
#   'Segheliin van Jerusalem',
#   'Sint Patricius',
#   'Sint Servaes legende',
#   'Sinte Franciscus leven',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft",
#   'Sinte Kerstine',
#   'Sinte Lutgard',
#   'Slag van Crecy',
#   'Speghel der wijsheit',
#   'Spiegel der jongers',
#   'Spiegel der sonden',
#   'Spiegel historiael (P1-P4)',
#   'Spiegel historiael (P2)',
#   'Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Beginsel der oorlogen van Luyck': ['Boec Exemplaer',
#   'Boec van den houte',
#   'Boec vander wraken',
#   'Boeve van Hamtone',
#   'Borchgrave van Couchi',
#   'Borchgravinne van Vergi (1)',
#   'Borchgravinne van Vergi (2)',
#   'Boudewijn van Seborch',
#   'Brabantsche yeesten (B1-5)',
#   'Brabantsche yeesten (B6)',
#   'Brabantsche yeesten (B7)',
#   "Chanson d'Aspremont",
#   'Collectief lunarium I',
#   'Collectief lunarium II',
#   'Collectief lunarium III',
#   'Commentaar op het Hooglied',
#   'Cyromanchie van den pape van den Hamme',
#   'Der leken spieghel',
#   'Der mannen ende vrouwen heimelijcheit',
#   'Der minnen loep',
#   'Der naturen bloeme',
#   'Der vrouwen heimelijcheit',
#   'Der ystorien bloeme',
#   'Dietsche Lucidarius',
#   'Dietsche doctrinale',
#   'Dystorie van Saladine',
#   'Enaamse Codex',
#   'Esopet',
#   'Expositie vanden viere vingheren ende vanden dume',
#   'Ferguut',
#   'Fierabras',
#   'Flandrijs',
#   'Florent ende Durant',
#   'Florigout',
#   'Florimont',
#   'Floris ende Blancefloer',
#   'Flovent',
#   'Floyris ende Blantseflur',
#   'Fysionomie',
#   'Gedicht over de hemeltekenen',
#   'Geraert van Viane',
#   'Godevaert metten baerde',
#   'Godevaerts kintshede',
#   'Grimbergse oorlog',
#   'Gwidekijn van Sassen',
#   'Heymelijchede der heymelijcheit',
#   'Historie van Gaver Capeel',
#   'Historie van Troyen',
#   'Huge van Bordeeus',
#   'Iechemas',
#   'Jan Splinters testament',
#   'Jans teesteye',
#   'Jonathas ende Rosafiere',
#   'Karel ende Elegast',
#   'Korte kroniek van Brabant (korte versie 1)',
#   'Korte kroniek van Brabant (lange versie)',
#   'Lanceloet en het hert met de witte voet',
#   'Lancelot',
#   'Lantsloot van der Haghedochte',
#   'Lapidarijs',
#   'Leven van Sint Trudo (berijming)',
#   'Limborch',
#   'Limburgse Aiol',
#   'Lion van Bourges',
#   'Loyhier en Malaert',
#   'Madelgijs',
#   'Melibeus',
#   'Merlijn',
#   'Merlijn-continuatie',
#   'Moriaen',
#   'Natuurkunde van het geheelal',
#   'Nevelingenlied',
#   'Nieuwe doctrinael',
#   'Noch die tien ghebode',
#   'Noch meer van wiven',
#   'Noch van Salladine',
#   'O crux lignum triumphale',
#   'Ogier van Denemarken',
#   'Ongeïdentificeerd (1)',
#   'Ongeïdentificeerd (2)',
#   'Ongeïdentificeerd (3)',
#   'Ongeïdentificeerd (4)',
#   'Ongeïdentificeerd (6)',
#   'Ongeïdentificeerd fragment',
#   'Ons heren passie',
#   'Parthonopeus van Bloys',
#   'Perchevael',
#   'Queeste van den Grale',
#   'Reinaerts historie',
#   'Reinout van Montalbaen',
#   'Renout van Montalbaen',
#   'Riddere metter mouwen',
#   'Rijmbijbel',
#   'Rijmkroniek van Holland',
#   'Rijmkroniek van Woeringen',
#   'Roelantslied',
#   'Roman der Lorreinen I',
#   'Roman der Lorreinen II',
#   'Roman van Antiochië',
#   'Roman van Caesar',
#   'Roman van Cassamus (kort)',
#   'Roman van Cassant',
#   'Rose',
#   'Rubben',
#   'Saladin',
#   'Schepping',
#   'Segheliin van Jerusalem',
#   'Sint Patricius',
#   'Sint Servaes legende',
#   'Sinte Franciscus leven',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft",
#   'Sinte Kerstine',
#   'Sinte Lutgard',
#   'Slag van Crecy',
#   'Speghel der wijsheit',
#   'Spiegel der jongers',
#   'Spiegel der sonden',
#   'Spiegel historiael (P1-P4)',
#   'Spiegel historiael (P2)',
#   'Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Boec Exemplaer': ['Boec van den houte',
#   'Boec vander wraken',
#   'Boeve van Hamtone',
#   'Borchgrave van Couchi',
#   'Borchgravinne van Vergi (1)',
#   'Borchgravinne van Vergi (2)',
#   'Boudewijn van Seborch',
#   'Brabantsche yeesten (B1-5)',
#   'Brabantsche yeesten (B6)',
#   'Brabantsche yeesten (B7)',
#   "Chanson d'Aspremont",
#   'Collectief lunarium I',
#   'Collectief lunarium II',
#   'Collectief lunarium III',
#   'Commentaar op het Hooglied',
#   'Cyromanchie van den pape van den Hamme',
#   'Der leken spieghel',
#   'Der mannen ende vrouwen heimelijcheit',
#   'Der minnen loep',
#   'Der naturen bloeme',
#   'Der vrouwen heimelijcheit',
#   'Der ystorien bloeme',
#   'Dietsche Lucidarius',
#   'Dietsche doctrinale',
#   'Dystorie van Saladine',
#   'Enaamse Codex',
#   'Esopet',
#   'Expositie vanden viere vingheren ende vanden dume',
#   'Ferguut',
#   'Fierabras',
#   'Flandrijs',
#   'Florent ende Durant',
#   'Florigout',
#   'Florimont',
#   'Floris ende Blancefloer',
#   'Flovent',
#   'Floyris ende Blantseflur',
#   'Fysionomie',
#   'Gedicht over de hemeltekenen',
#   'Geraert van Viane',
#   'Godevaert metten baerde',
#   'Godevaerts kintshede',
#   'Grimbergse oorlog',
#   'Gwidekijn van Sassen',
#   'Heymelijchede der heymelijcheit',
#   'Historie van Gaver Capeel',
#   'Historie van Troyen',
#   'Huge van Bordeeus',
#   'Iechemas',
#   'Jan Splinters testament',
#   'Jans teesteye',
#   'Jonathas ende Rosafiere',
#   'Karel ende Elegast',
#   'Korte kroniek van Brabant (korte versie 1)',
#   'Korte kroniek van Brabant (lange versie)',
#   'Lanceloet en het hert met de witte voet',
#   'Lancelot',
#   'Lantsloot van der Haghedochte',
#   'Lapidarijs',
#   'Leven van Sint Trudo (berijming)',
#   'Limborch',
#   'Limburgse Aiol',
#   'Lion van Bourges',
#   'Loyhier en Malaert',
#   'Madelgijs',
#   'Melibeus',
#   'Merlijn',
#   'Merlijn-continuatie',
#   'Moriaen',
#   'Natuurkunde van het geheelal',
#   'Nevelingenlied',
#   'Nieuwe doctrinael',
#   'Noch die tien ghebode',
#   'Noch meer van wiven',
#   'Noch van Salladine',
#   'O crux lignum triumphale',
#   'Ogier van Denemarken',
#   'Ongeïdentificeerd (1)',
#   'Ongeïdentificeerd (2)',
#   'Ongeïdentificeerd (3)',
#   'Ongeïdentificeerd (4)',
#   'Ongeïdentificeerd (6)',
#   'Ongeïdentificeerd fragment',
#   'Ons heren passie',
#   'Parthonopeus van Bloys',
#   'Perchevael',
#   'Queeste van den Grale',
#   'Reinaerts historie',
#   'Reinout van Montalbaen',
#   'Renout van Montalbaen',
#   'Riddere metter mouwen',
#   'Rijmbijbel',
#   'Rijmkroniek van Holland',
#   'Rijmkroniek van Woeringen',
#   'Roelantslied',
#   'Roman der Lorreinen I',
#   'Roman der Lorreinen II',
#   'Roman van Antiochië',
#   'Roman van Caesar',
#   'Roman van Cassamus (kort)',
#   'Roman van Cassant',
#   'Rose',
#   'Rubben',
#   'Saladin',
#   'Schepping',
#   'Segheliin van Jerusalem',
#   'Sint Patricius',
#   'Sint Servaes legende',
#   'Sinte Franciscus leven',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft",
#   'Sinte Kerstine',
#   'Sinte Lutgard',
#   'Slag van Crecy',
#   'Speghel der wijsheit',
#   'Spiegel der jongers',
#   'Spiegel der sonden',
#   'Spiegel historiael (P1-P4)',
#   'Spiegel historiael (P2)',
#   'Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Boec van den houte': ['Boec vander wraken',
#   'Boeve van Hamtone',
#   'Borchgrave van Couchi',
#   'Borchgravinne van Vergi (1)',
#   'Borchgravinne van Vergi (2)',
#   'Boudewijn van Seborch',
#   'Brabantsche yeesten (B1-5)',
#   'Brabantsche yeesten (B6)',
#   'Brabantsche yeesten (B7)',
#   "Chanson d'Aspremont",
#   'Collectief lunarium I',
#   'Collectief lunarium II',
#   'Collectief lunarium III',
#   'Commentaar op het Hooglied',
#   'Cyromanchie van den pape van den Hamme',
#   'Der leken spieghel',
#   'Der mannen ende vrouwen heimelijcheit',
#   'Der minnen loep',
#   'Der naturen bloeme',
#   'Der vrouwen heimelijcheit',
#   'Der ystorien bloeme',
#   'Dietsche Lucidarius',
#   'Dietsche doctrinale',
#   'Dystorie van Saladine',
#   'Enaamse Codex',
#   'Esopet',
#   'Expositie vanden viere vingheren ende vanden dume',
#   'Ferguut',
#   'Fierabras',
#   'Flandrijs',
#   'Florent ende Durant',
#   'Florigout',
#   'Florimont',
#   'Floris ende Blancefloer',
#   'Flovent',
#   'Floyris ende Blantseflur',
#   'Fysionomie',
#   'Gedicht over de hemeltekenen',
#   'Geraert van Viane',
#   'Godevaert metten baerde',
#   'Godevaerts kintshede',
#   'Grimbergse oorlog',
#   'Gwidekijn van Sassen',
#   'Heymelijchede der heymelijcheit',
#   'Historie van Gaver Capeel',
#   'Historie van Troyen',
#   'Huge van Bordeeus',
#   'Iechemas',
#   'Jan Splinters testament',
#   'Jans teesteye',
#   'Jonathas ende Rosafiere',
#   'Karel ende Elegast',
#   'Korte kroniek van Brabant (korte versie 1)',
#   'Korte kroniek van Brabant (lange versie)',
#   'Lanceloet en het hert met de witte voet',
#   'Lancelot',
#   'Lantsloot van der Haghedochte',
#   'Lapidarijs',
#   'Leven van Sint Trudo (berijming)',
#   'Limborch',
#   'Limburgse Aiol',
#   'Lion van Bourges',
#   'Loyhier en Malaert',
#   'Madelgijs',
#   'Melibeus',
#   'Merlijn',
#   'Merlijn-continuatie',
#   'Moriaen',
#   'Natuurkunde van het geheelal',
#   'Nevelingenlied',
#   'Nieuwe doctrinael',
#   'Noch die tien ghebode',
#   'Noch meer van wiven',
#   'Noch van Salladine',
#   'O crux lignum triumphale',
#   'Ogier van Denemarken',
#   'Ongeïdentificeerd (1)',
#   'Ongeïdentificeerd (2)',
#   'Ongeïdentificeerd (3)',
#   'Ongeïdentificeerd (4)',
#   'Ongeïdentificeerd (6)',
#   'Ongeïdentificeerd fragment',
#   'Ons heren passie',
#   'Parthonopeus van Bloys',
#   'Perchevael',
#   'Queeste van den Grale',
#   'Reinaerts historie',
#   'Reinout van Montalbaen',
#   'Renout van Montalbaen',
#   'Riddere metter mouwen',
#   'Rijmbijbel',
#   'Rijmkroniek van Holland',
#   'Rijmkroniek van Woeringen',
#   'Roelantslied',
#   'Roman der Lorreinen I',
#   'Roman der Lorreinen II',
#   'Roman van Antiochië',
#   'Roman van Caesar',
#   'Roman van Cassamus (kort)',
#   'Roman van Cassant',
#   'Rose',
#   'Rubben',
#   'Saladin',
#   'Schepping',
#   'Segheliin van Jerusalem',
#   'Sint Patricius',
#   'Sint Servaes legende',
#   'Sinte Franciscus leven',
#   "Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft",
#   'Sinte Kerstine',
#   'Sinte Lutgard',
#   'Slag van Crecy',
#   'Speghel der wijsheit',
#   'Spiegel der jongers',
#   'Spiegel der sonden',
#   'Spiegel historiael (P1-P4)',
#   'Spiegel historiael (P2)',
#   'Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
# ...
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Spiegel historiael (P1-P4)': ['Spiegel historiael (P2)',
#   'Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Spiegel historiael (P2)': ['Spiegel historiael (P4)',
#   'Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Spiegel historiael (P4)': ['Spiegel historiael (P5)',
#   'Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Spiegel historiael (P5)': ['Spieghel der menscheliker behoudenesse',
#   'Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Spieghel der menscheliker behoudenesse': ['Theophilus',
#   'Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Theophilus': ['Tien plaghen ende die tien ghebode',
#   'Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Tien plaghen ende die tien ghebode': ['Torec',
#   'Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Torec': ['Tristant',
#   'Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Tristant': ['Valentijn en Nameloos',
#   'Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Valentijn en Nameloos': ['Van Saladijn',
#   'Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Van Saladijn': ['Van den VII Vroeden van binnen Rome',
#   'Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Van den VII Vroeden van binnen Rome': ['Van den derden Eduwaert',
#   'Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Van den derden Eduwaert': ['Van den neghen besten (kort)',
#   'Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Van den neghen besten (kort)': ['Van den neghen besten (lang)',
#   'Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Van den neghen besten (lang)': ['Van den vijf vrouden',
#   'Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Van den vijf vrouden': ['Van den vos Reynaerde',
#   'Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Van den vos Reynaerde': ['Van der manen zeden',
#   'Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Van der manen zeden': ['Van der wive wonderlijcheit (lange versie)',
#   'Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Van der wive wonderlijcheit (lange versie)': ['Van ghevene',
#   'Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Van ghevene': ['Van sente Brandane',
#   'Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Van sente Brandane': ['Van ses vaerwen ende twaelf outheyden',
#   'Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Van ses vaerwen ende twaelf outheyden': ['Van smeinscen lede',
#   'Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Van smeinscen lede': ['Vande Hertogen ende Heeren van Brabant',
#   'Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Vande Hertogen ende Heeren van Brabant': ['Vanden levene ons heren',
#   'Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Vanden levene ons heren': ['Vander rijcheit ende vander doot',
#   'Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Vander rijcheit ende vander doot': ['Vlaamse Aiol',
#   'Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Vlaamse Aiol': ['Vlaamse Rose',
#   'Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Vlaamse Rose': ['Walewein (Penninc)',
#   'Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Walewein (Penninc)': ['Walewein (Vostaert)',
#   'Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Walewein (Vostaert)': ['Walewein ende Keye',
#   'Willem van Oringen',
#   'Wisselau',
#   'Wrake van Ragisel'],
#  'Walewein ende Keye': ['Willem van Oringen', 'Wisselau', 'Wrake van Ragisel'],
#  'Willem van Oringen': ['Wisselau', 'Wrake van Ragisel'],
#  'Wisselau': ['Wrake van Ragisel']}

# %% [markdown]
# The following block (which takes a while to run) runs over all text combinations and calculates the distance between all of the respective verse groups. We keep track of the length of both texts in the pair and count the number of "hits", or combinations of verse groups that have a smaller distance than the threshold value, which we found to be optimal in the manually annotated data:

# %%
results, intertexts = [], []

for cnt, t1 in enumerate(lookup):
    print(t1, f'{cnt+1}/{len(lookup)}')
    a1 = meta_df[meta_df['title'] == t1]['author'].iloc[0]
    g1 = meta_df[meta_df['title'] == t1]['genre'].iloc[0]
    sg1 = meta_df[meta_df['title'] == t1]['subgenre'].iloc[0]
    
    A = df[df['title'] == t1]
    AX = vec.transform(A['lemmas']) + optim_rw * vec.transform(A['rhyme'])
    
    for t2 in tqdm(lookup[t1]):
        a2 = meta_df[meta_df['title'] == t2]['author'].iloc[0] 
        g2 = meta_df[meta_df['title'] == t2]['genre'].iloc[0]
        sg2 = meta_df[meta_df['title'] == t2]['subgenre'].iloc[0]
        
        B = df[df['title'] == t2]
        BX = vec.transform(B['lemmas']) + optim_rw * vec.transform(B['rhyme'])
        
        # get NNs for statistics
        distances = pairwise(AX, BX, batch_size=10000)
        l1, l2 = len(df[df['title'] == t1]), len(df[df['title'] == t2])
        hits = np.sum(distances <= optim_th)
        results.append((t1, t2, l1, l2, hits, g1, g2, sg1, sg2, a1, a2))
    
        # collect actual intertexts
        #intertexts.append(retrieve_intertexts(t1, t2, distances=distances, threshold=threshold))
    
#intertexts = pd.concat(intertexts)
#intertexts.to_excel('../figures/intertexts.xlsx', index=False)

results = pd.DataFrame(results, columns=['t1', 't2',
                                         'l1', 'l2', 'hits',
                                         'genre1', 'genre2',
                                         'subgenre1', 'subgenre2',
                                         'author1', 'author2'])
results['hit_ratio'] = results['hits'] / (results['l1'] * results['l2'])
results = results.sort_values(by='hit_ratio', ascending=False)
results.to_excel('../figures/statistics.xlsx', index=False)
results
# Out:
# Alexanders geesten 1/160
# 100%|██████████| 160/160 [02:37<00:00,  1.02it/s]
# Alexiuslegende 2/160
# 100%|██████████| 159/159 [00:16<00:00,  9.43it/s]
# Anatomie van de mens 3/160
# 100%|██████████| 158/158 [00:17<00:00,  8.94it/s]
# Arturs doet 4/160
# 100%|██████████| 157/157 [02:20<00:00,  1.12it/s]
# Aubri de Borgengoen 5/160
# 100%|██████████| 156/156 [00:18<00:00,  8.25it/s]
# Barlaam en Josaphat 6/160
# 100%|██████████| 155/155 [00:17<00:00,  8.84it/s]
# Beatrijs 7/160
# 100%|██████████| 154/154 [00:24<00:00,  6.38it/s]
# Bediedenisse van der missen 8/160
# 100%|██████████| 153/153 [00:26<00:00,  5.84it/s]
# Beerte metten breden voeten 9/160
# 100%|██████████| 152/152 [00:17<00:00,  8.88it/s]
# Beginsel der oorlogen van Luyck 10/160
# 100%|██████████| 151/151 [00:20<00:00,  7.49it/s]
# Boec Exemplaer 11/160
# 100%|██████████| 150/150 [00:17<00:00,  8.33it/s]
# Boec van den houte 12/160
# 100%|██████████| 149/149 [00:22<00:00,  6.58it/s]
# Boec vander wraken 13/160
# 100%|██████████| 148/148 [01:01<00:00,  2.41it/s]
# Boeve van Hamtone 14/160
# 100%|██████████| 147/147 [00:16<00:00,  8.70it/s]
# Borchgrave van Couchi 15/160
# 100%|██████████| 146/146 [00:47<00:00,  3.07it/s]
# Borchgravinne van Vergi (1) 16/160
# 100%|██████████| 145/145 [00:24<00:00,  5.98it/s]
# Borchgravinne van Vergi (2) 17/160
# 100%|██████████| 144/144 [00:18<00:00,  7.61it/s]
# Boudewijn van Seborch 18/160
# 100%|██████████| 143/143 [00:18<00:00,  7.89it/s]
# Brabantsche yeesten (B1-5) 19/160
# 100%|██████████| 142/142 [01:10<00:00,  2.03it/s]
# Brabantsche yeesten (B6) 20/160
# 100%|██████████| 141/141 [02:10<00:00,  1.08it/s]
# Brabantsche yeesten (B7) 21/160
# 100%|██████████| 140/140 [03:11<00:00,  1.36s/it]
# Chanson d'Aspremont 22/160
# 100%|██████████| 139/139 [00:15<00:00,  9.17it/s]
# Collectief lunarium I 23/160
# 100%|██████████| 138/138 [00:15<00:00,  8.90it/s]
# Collectief lunarium II 24/160
# 100%|██████████| 137/137 [00:17<00:00,  7.74it/s]
# Collectief lunarium III 25/160
# 100%|██████████| 136/136 [00:17<00:00,  7.72it/s]
# Commentaar op het Hooglied 26/160
# 100%|██████████| 135/135 [01:45<00:00,  1.28it/s]
# Cyromanchie van den pape van den Hamme 27/160
# 100%|██████████| 134/134 [00:18<00:00,  7.27it/s]
# Der leken spieghel 28/160
# 100%|██████████| 133/133 [04:40<00:00,  2.11s/it]
# Der mannen ende vrouwen heimelijcheit 29/160
# 100%|██████████| 132/132 [00:31<00:00,  4.21it/s]
# Der minnen loep 30/160
# 100%|██████████| 131/131 [01:46<00:00,  1.23it/s]
# Der naturen bloeme 31/160
# 100%|██████████| 130/130 [02:31<00:00,  1.17s/it]
# Der vrouwen heimelijcheit 32/160
# 100%|██████████| 129/129 [00:25<00:00,  5.15it/s]
# Der ystorien bloeme 33/160
# 100%|██████████| 128/128 [00:44<00:00,  2.88it/s]
# Dietsche Lucidarius 34/160
# 100%|██████████| 127/127 [00:57<00:00,  2.20it/s]
# Dietsche doctrinale 35/160
# 100%|██████████| 126/126 [00:59<00:00,  2.12it/s]
# Dystorie van Saladine 36/160
# 100%|██████████| 125/125 [00:24<00:00,  5.01it/s]
# Enaamse Codex 37/160
# 100%|██████████| 124/124 [00:37<00:00,  3.28it/s]
# Esopet 38/160
# 100%|██████████| 123/123 [00:23<00:00,  5.22it/s]
# Expositie vanden viere vingheren ende vanden dume 39/160
# 100%|██████████| 122/122 [00:14<00:00,  8.55it/s]
# Ferguut 40/160
# 100%|██████████| 121/121 [00:50<00:00,  2.40it/s]
# Fierabras 41/160
# 100%|██████████| 120/120 [00:14<00:00,  8.43it/s]
# Flandrijs 42/160
# 100%|██████████| 119/119 [00:25<00:00,  4.76it/s]
# Florent ende Durant 43/160
# 100%|██████████| 118/118 [00:13<00:00,  8.94it/s]
# Florigout 44/160
# 100%|██████████| 117/117 [00:19<00:00,  6.05it/s]
# Florimont 45/160
# 100%|██████████| 116/116 [00:14<00:00,  8.26it/s]
# Floris ende Blancefloer 46/160
# 100%|██████████| 115/115 [00:40<00:00,  2.87it/s]
# Flovent 47/160
# 100%|██████████| 114/114 [00:15<00:00,  7.18it/s]
# Floyris ende Blantseflur 48/160
# 100%|██████████| 113/113 [00:13<00:00,  8.37it/s]
# Fysionomie 49/160
# 100%|██████████| 112/112 [00:13<00:00,  8.30it/s]
# Gedicht over de hemeltekenen 50/160
# 100%|██████████| 111/111 [00:12<00:00,  8.89it/s]
# Geraert van Viane 51/160
# 100%|██████████| 110/110 [00:12<00:00,  8.75it/s]
# Godevaert metten baerde 52/160
# 100%|██████████| 109/109 [00:11<00:00,  9.24it/s]
# Godevaerts kintshede 53/160
# 100%|██████████| 108/108 [00:11<00:00,  9.28it/s]
# Grimbergse oorlog 54/160
# 100%|██████████| 107/107 [01:42<00:00,  1.04it/s]
# Gwidekijn van Sassen 55/160
# 100%|██████████| 106/106 [01:48<00:00,  1.02s/it]
# Heymelijchede der heymelijcheit 56/160
# 100%|██████████| 105/105 [00:36<00:00,  2.90it/s]
# Historie van Gaver Capeel 57/160
# 100%|██████████| 104/104 [00:11<00:00,  8.73it/s]
# Historie van Troyen 58/160
# 100%|██████████| 103/103 [15:38<00:00,  9.11s/it]
# Huge van Bordeeus 59/160
# 100%|██████████| 102/102 [00:16<00:00,  6.26it/s]
# Iechemas 60/160
# 100%|██████████| 101/101 [00:13<00:00,  7.60it/s]
# Jan Splinters testament 61/160
# 100%|██████████| 100/100 [00:11<00:00,  8.49it/s]
# Jans teesteye 62/160
# 100%|██████████| 99/99 [00:34<00:00,  2.86it/s]
# Jonathas ende Rosafiere 63/160
# 100%|██████████| 98/98 [00:18<00:00,  5.25it/s]
# Karel ende Elegast 64/160
# 100%|██████████| 97/97 [00:18<00:00,  5.31it/s]
# Korte kroniek van Brabant (korte versie 1) 65/160
# 100%|██████████| 96/96 [00:12<00:00,  7.68it/s]
# Korte kroniek van Brabant (lange versie) 66/160
# 100%|██████████| 95/95 [00:22<00:00,  4.25it/s]
# Lanceloet en het hert met de witte voet 67/160
# 100%|██████████| 94/94 [00:15<00:00,  6.25it/s]
# Lancelot 68/160
# 100%|██████████| 93/93 [09:27<00:00,  6.11s/it]
# Lantsloot van der Haghedochte 69/160
# 100%|██████████| 92/92 [00:42<00:00,  2.14it/s]
# Lapidarijs 70/160
# 100%|██████████| 91/91 [00:11<00:00,  8.06it/s]
# Leven van Sint Trudo (berijming) 71/160
# 100%|██████████| 90/90 [00:11<00:00,  8.09it/s]
# Limborch 72/160
# 100%|██████████| 89/89 [03:35<00:00,  2.42s/it]
# Limburgse Aiol 73/160
# 100%|██████████| 88/88 [00:11<00:00,  7.34it/s]
# Lion van Bourges 74/160
# 100%|██████████| 87/87 [00:09<00:00,  8.79it/s]
# Loyhier en Malaert 75/160
# 100%|██████████| 86/86 [00:11<00:00,  7.71it/s]
# Madelgijs 76/160
# 100%|██████████| 85/85 [00:20<00:00,  4.20it/s]
# Melibeus 77/160
# 100%|██████████| 84/84 [01:02<00:00,  1.34it/s]
# Merlijn 78/160
# 100%|██████████| 83/83 [50:50<00:00, 36.75s/it]
# Merlijn-continuatie 79/160
# 100%|██████████| 82/82 [1:10:45<00:00, 51.78s/it]
# Moriaen 80/160
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# Natuurkunde van het geheelal 81/160
# 100%|██████████| 80/80 [00:15<00:00,  5.00it/s]
# Nevelingenlied 82/160
# 100%|██████████| 79/79 [00:08<00:00,  8.87it/s]
# Nieuwe doctrinael 83/160
# 100%|██████████| 78/78 [00:21<00:00,  3.68it/s]
# Noch die tien ghebode 84/160
# 100%|██████████| 77/77 [00:08<00:00,  8.92it/s]
# Noch meer van wiven 85/160
# 100%|██████████| 76/76 [00:08<00:00,  8.80it/s]
# Noch van Salladine 86/160
# 100%|██████████| 75/75 [00:08<00:00,  9.19it/s]
# O crux lignum triumphale 87/160
# 100%|██████████| 74/74 [00:11<00:00,  6.45it/s]
# Ogier van Denemarken 88/160
# 100%|██████████| 73/73 [00:10<00:00,  7.03it/s]
# Ongeïdentificeerd (1) 89/160
# 100%|██████████| 72/72 [00:08<00:00,  8.66it/s]
# Ongeïdentificeerd (2) 90/160
# 100%|██████████| 71/71 [00:07<00:00,  9.12it/s]
# Ongeïdentificeerd (3) 91/160
# 100%|██████████| 70/70 [02:08<00:00,  1.83s/it]
# Ongeïdentificeerd (4) 92/160
# 100%|██████████| 69/69 [00:07<00:00,  9.02it/s]
# Ongeïdentificeerd (6) 93/160
# 100%|██████████| 68/68 [01:39<00:00,  1.47s/it]
# Ongeïdentificeerd fragment 94/160
# 100%|██████████| 67/67 [00:07<00:00,  8.92it/s]
# Ons heren passie 95/160
# 100%|██████████| 66/66 [01:27<00:00,  1.33s/it]
# Parthonopeus van Bloys 96/160
# 100%|██████████| 65/65 [00:48<00:00,  1.35it/s]
# Perchevael 97/160
# 100%|██████████| 64/64 [00:24<00:00,  2.66it/s]
# Queeste van den Grale 98/160
# 100%|██████████| 63/63 [01:02<00:00,  1.01it/s]
# Reinaerts historie 99/160
# 100%|██████████| 62/62 [00:25<00:00,  2.45it/s]
# Reinout van Montalbaen 100/160
# 100%|██████████| 61/61 [00:06<00:00,  8.80it/s]
# Renout van Montalbaen 101/160
# 100%|██████████| 60/60 [00:16<00:00,  3.59it/s]
# Riddere metter mouwen 102/160
# 100%|██████████| 59/59 [00:21<00:00,  2.78it/s]
# Rijmbijbel 103/160
# 100%|██████████| 58/58 [07:41<00:00,  7.96s/it]
# Rijmkroniek van Holland 104/160
# 100%|██████████| 57/57 [01:05<00:00,  1.15s/it]
# Rijmkroniek van Woeringen 105/160
# 100%|██████████| 56/56 [00:39<00:00,  1.42it/s]
# Roelantslied 106/160
# 100%|██████████| 55/55 [00:10<00:00,  5.47it/s]
# Roman der Lorreinen I 107/160
# 100%|██████████| 54/54 [00:08<00:00,  6.16it/s]
# Roman der Lorreinen II 108/160
# 100%|██████████| 53/53 [00:39<00:00,  1.34it/s]
# Roman van Antiochië 109/160
# 100%|██████████| 52/52 [00:06<00:00,  8.47it/s]
# Roman van Caesar 110/160
# 100%|██████████| 51/51 [00:08<00:00,  5.68it/s]
# Roman van Cassamus (kort) 111/160
# 100%|██████████| 50/50 [00:11<00:00,  4.28it/s]
# Roman van Cassant 112/160
# 100%|██████████| 49/49 [00:05<00:00,  9.03it/s]
# Rose 113/160
# 100%|██████████| 48/48 [00:58<00:00,  1.22s/it]
# Rubben 114/160
# 100%|██████████| 47/47 [00:05<00:00,  7.97it/s]
# Saladin 115/160
# 100%|██████████| 46/46 [00:05<00:00,  8.39it/s]
# Schepping 116/160
# 100%|██████████| 45/45 [00:05<00:00,  7.69it/s]
# Segheliin van Jerusalem 117/160
# 100%|██████████| 44/44 [00:41<00:00,  1.06it/s]
# Sint Patricius 118/160
# 100%|██████████| 43/43 [00:06<00:00,  7.10it/s]
# Sint Servaes legende 119/160
# 100%|██████████| 42/42 [00:22<00:00,  1.84it/s]
# Sinte Franciscus leven 120/160
# 100%|██████████| 41/41 [00:37<00:00,  1.09it/s]
# Sinte Jans ewangelium alsoe 't Augustijnken gheexponeert heeft 121/160
# 100%|██████████| 40/40 [00:07<00:00,  5.48it/s]
# Sinte Kerstine 122/160
# 100%|██████████| 39/39 [00:10<00:00,  3.86it/s]
# Sinte Lutgard 123/160
# 100%|██████████| 38/38 [01:47<00:00,  2.84s/it]
# Slag van Crecy 124/160
# 100%|██████████| 37/37 [00:04<00:00,  8.26it/s]
# Speghel der wijsheit 125/160
# 100%|██████████| 36/36 [00:15<00:00,  2.35it/s]
# Spiegel der jongers 126/160
# 100%|██████████| 35/35 [00:05<00:00,  6.81it/s]
# Spiegel der sonden 127/160
# 100%|██████████| 34/34 [00:53<00:00,  1.56s/it]
# Spiegel historiael (P1-P4) 128/160
# 100%|██████████| 33/33 [09:11<00:00, 16.71s/it]
# Spiegel historiael (P2) 129/160
# 100%|██████████| 32/32 [00:44<00:00,  1.38s/it]
# Spiegel historiael (P4) 130/160
# 100%|██████████| 31/31 [00:08<00:00,  3.48it/s]
# Spiegel historiael (P5) 131/160
# 100%|██████████| 30/30 [00:16<00:00,  1.78it/s]
# Spieghel der menscheliker behoudenesse 132/160
# 100%|██████████| 29/29 [00:10<00:00,  2.80it/s]
# Theophilus 133/160
# 100%|██████████| 28/28 [00:03<00:00,  8.47it/s]
# Tien plaghen ende die tien ghebode 134/160
# 100%|██████████| 27/27 [00:03<00:00,  7.89it/s]
# Torec 135/160
# 100%|██████████| 26/26 [00:03<00:00,  7.45it/s]
# Tristant 136/160
# 100%|██████████| 25/25 [00:02<00:00, 11.49it/s]
# Valentijn en Nameloos 137/160
# 100%|██████████| 24/24 [00:02<00:00, 10.31it/s]
# Van Saladijn 138/160
# 100%|██████████| 23/23 [00:02<00:00, 10.90it/s]
# Van den VII Vroeden van binnen Rome 139/160
# 100%|██████████| 22/22 [00:03<00:00,  6.00it/s]
# Van den derden Eduwaert 140/160
# 100%|██████████| 21/21 [00:02<00:00,  8.26it/s]
# Van den neghen besten (kort) 141/160
# 100%|██████████| 20/20 [00:01<00:00, 11.53it/s]
# Van den neghen besten (lang) 142/160
# 100%|██████████| 19/19 [00:01<00:00, 10.08it/s]
# Van den vijf vrouden 143/160
# 100%|██████████| 18/18 [00:01<00:00, 11.48it/s]
# Van den vos Reynaerde 144/160
# 100%|██████████| 17/17 [00:02<00:00,  6.54it/s]
# Van der manen zeden 145/160
# 100%|██████████| 16/16 [00:01<00:00, 10.83it/s]
# Van der wive wonderlijcheit (lange versie) 146/160
# 100%|██████████| 15/15 [00:01<00:00, 11.06it/s]
# Van ghevene 147/160
# 100%|██████████| 14/14 [00:01<00:00, 11.18it/s]
# Van sente Brandane 148/160
# 100%|██████████| 13/13 [00:01<00:00,  7.36it/s]
# Van ses vaerwen ende twaelf outheyden 149/160
# 100%|██████████| 12/12 [00:01<00:00, 10.63it/s]
# Van smeinscen lede 150/160
# 100%|██████████| 11/11 [00:01<00:00,  7.26it/s]
# Vande Hertogen ende Heeren van Brabant 151/160
# 100%|██████████| 10/10 [00:00<00:00, 10.18it/s]
# Vanden levene ons heren 152/160
# 100%|██████████| 9/9 [00:01<00:00,  4.73it/s]
# Vander rijcheit ende vander doot 153/160
# 100%|██████████| 8/8 [00:00<00:00, 10.87it/s]
# Vlaamse Aiol 154/160
# 100%|██████████| 7/7 [00:00<00:00,  7.88it/s]
# Vlaamse Rose 155/160
# 100%|██████████| 6/6 [00:01<00:00,  5.79it/s]
# Walewein (Penninc) 156/160
# 100%|██████████| 5/5 [00:01<00:00,  4.15it/s]
# Walewein (Vostaert) 157/160
# 100%|██████████| 4/4 [00:00<00:00,  7.20it/s]
# Walewein ende Keye 158/160
# 100%|██████████| 3/3 [00:00<00:00,  8.95it/s]
# Willem van Oringen 159/160
# 100%|██████████| 2/2 [00:00<00:00, 11.47it/s]
# Wisselau 160/160
# 100%|██████████| 1/1 [00:00<00:00, 10.16it/s]
#                              t1                                          t2  \
# 10014  Noch meer van wiven       Van der wive wonderlijcheit (lange versie)
# 7245   Gwidekijn van Sassen      Ongeïdentificeerd (4)
# 10484  Ongeïdentificeerd (4)     Roman van Cassant
# 7265   Gwidekijn van Sassen      Roman van Cassant
# 10481  Ongeïdentificeerd (4)     Roman van Antiochië
# ...                      ...                     ...
# 7086   Godevaerts kintshede      Van der wive wonderlijcheit (lange versie)
# 7085   Godevaerts kintshede      Van der manen zeden
# 7083   Godevaerts kintshede      Van den vijf vrouden
# 7078   Godevaerts kintshede      Van Saladijn
# 6440   Floyris ende Blantseflur  Gedicht over de hemeltekenen
#
#         l1   l2  hits genre1 genre2   subgenre1   subgenre2 author1  \
# 10014  111  225  149   Epiek  Epiek  Didactiek   Didactiek   NaN
# 7245   199  139  35    Epiek  Epiek  Karel       Karel       NaN
# 10484  139  29   5     Epiek  Epiek  Karel       Kruisvaart  NaN
# 7265   199  29   5     Epiek  Epiek  Karel       Kruisvaart  NaN
# 10481  139  168  16    Epiek  Epiek  Karel       Kruisvaart  NaN
# ...    ...  ...  ..      ...    ...    ...              ...  ...
# 7086   55   225  0     Epiek  Epiek  Kruisvaart  Didactiek   NaN
# 7085   55   301  0     Epiek  Epiek  Kruisvaart  Didactiek   NaN
# 7083   55   72   0     Epiek  Epiek  Kruisvaart  Didactiek   NaN
# 7078   55   289  0     Epiek  Epiek  Kruisvaart  Kruisvaart  NaN
# 6440   313  154  0     Epiek  Epiek  Ridder      Didactiek   NaN
#
#              author2  hit_ratio
# 10014  NaN            0.005966
# 7245   NaN            0.001265
# 10484  NaN            0.001240
# 7265   NaN            0.000866
# 10481  NaN            0.000685
# ...    ...                 ...
# 7086   NaN            0.000000
# 7085   NaN            0.000000
# 7083   NaN            0.000000
# 7078   Hein van Aken  0.000000
# 6440   NaN            0.000000
#
# [12880 rows x 12 columns]
